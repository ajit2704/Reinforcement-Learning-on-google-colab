# %% [markdown]
# <a href="https://colab.research.google.com/github/ajit2704/Practical-Reinforcement-Learning-With-Colab/blob/master/A3C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gym
# Out:
# Collecting gym
#   Downloading https://files.pythonhosted.org/packages/9b/50/ed4a03d2be47ffd043be2ee514f329ce45d98a30fe2d1b9c61dea5a9d861/gym-0.10.5.tar.gz (1.5MB)
#     100% |████████████████████████████████| 1.5MB 18.8MB/s
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.14.5)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym) (1.11.0)
# Collecting pyglet>=1.2.0 (from gym)
#   Downloading https://files.pythonhosted.org/packages/1c/fc/dad5eaaab68f0c21e2f906a94ddb98175662cc5a654eee404d59554ce0fa/pyglet-1.3.2-py2.py3-none-any.whl (1.0MB)
#     100% |████████████████████████████████| 1.0MB 25.8MB/s
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (2018.4.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (3.0.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym) (0.16.0)
# Building wheels for collected packages: gym
# done
#   Stored in directory: /content/.cache/pip/wheels/cb/14/71/f4ab006b1e6ff75c2b54985c2f98d0644fffe9c1dddc670925
# Successfully built gym
# Installing collected packages: pyglet, gym
# Successfully installed gym-0.10.5 pyglet-1.3.2

# %%
# !apt-get install python-opengl -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   freeglut3 libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2
#   libdrm-radeon1 libdrm2 libelf1 libgl1-mesa-dri libgl1-mesa-glx libglapi-mesa
#   libglu1-mesa libllvm5.0 libpciaccess0 libsensors4 libtxc-dxtn-s2tc
#   libx11-xcb1 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0
#   libxcb-sync1 libxdamage1 libxfixes3 libxi6 libxshmfence1 libxxf86vm1
# Suggested packages:
#   pciutils lm-sensors python-numpy libgle3
# The following NEW packages will be installed:
#   freeglut3 libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2
#   libdrm-radeon1 libdrm2 libelf1 libgl1-mesa-dri libgl1-mesa-glx libglapi-mesa
#   libglu1-mesa libllvm5.0 libpciaccess0 libsensors4 libtxc-dxtn-s2tc
#   libx11-xcb1 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0
#   libxcb-sync1 libxdamage1 libxfixes3 libxi6 libxshmfence1 libxxf86vm1
#   python-opengl
# 0 upgraded, 28 newly installed, 0 to remove and 7 not upgraded.
# Need to get 20.7 MB of archives.
# After this operation, 194 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful/main amd64 libxshmfence1 amd64 1.2-1 [5,042 B]
# Get:2 http://archive.ubuntu.com/ubuntu artful/main amd64 libxxf86vm1 amd64 1:1.1.4-1 [10.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu artful/main amd64 libelf1 amd64 0.170-0.1 [44.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-common all 2.4.83-1 [4,938 B]
# Get:5 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm2 amd64 2.4.83-1 [30.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libglapi-mesa amd64 17.2.8-0ubuntu0~17.10.1 [22.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu artful/main amd64 libx11-xcb1 amd64 2:1.6.4-3 [9,626 B]
# Get:8 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-dri2-0 amd64 1.12-1ubuntu1 [6,838 B]
# Get:9 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-dri3-0 amd64 1.12-1ubuntu1 [5,156 B]
# Get:10 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-glx0 amd64 1.12-1ubuntu1 [22.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-present0 amd64 1.12-1ubuntu1 [5,436 B]
# Get:12 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-sync1 amd64 1.12-1ubuntu1 [8,746 B]
# Get:13 http://archive.ubuntu.com/ubuntu artful/main amd64 libxdamage1 amd64 1:1.1.4-3 [6,934 B]
# Get:14 http://archive.ubuntu.com/ubuntu artful/main amd64 libxfixes3 amd64 1:5.0.3-1 [10.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-amdgpu1 amd64 2.4.83-1 [18.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu artful/main amd64 libpciaccess0 amd64 0.13.4-1ubuntu1 [17.9 kB]
# Get:17 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-intel1 amd64 2.4.83-1 [59.7 kB]
# Get:18 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-nouveau2 amd64 2.4.83-1 [16.4 kB]
# Get:19 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-radeon1 amd64 2.4.83-1 [21.6 kB]
# Get:20 http://archive.ubuntu.com/ubuntu artful/main amd64 libllvm5.0 amd64 1:5.0-3 [13.7 MB]
# Get:21 http://archive.ubuntu.com/ubuntu artful/main amd64 libsensors4 amd64 1:3.4.0-4 [28.8 kB]
# Get:22 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgl1-mesa-dri amd64 17.2.8-0ubuntu0~17.10.1 [5,707 kB]
# Get:23 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgl1-mesa-glx amd64 17.2.8-0ubuntu0~17.10.1 [130 kB]
# Get:24 http://archive.ubuntu.com/ubuntu artful/main amd64 libxi6 amd64 2:1.7.9-1 [29.2 kB]
# Get:25 http://archive.ubuntu.com/ubuntu artful/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu artful/main amd64 libglu1-mesa amd64 9.0.0-2.1build1 [168 kB]
# Get:27 http://archive.ubuntu.com/ubuntu artful/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Get:28 http://archive.ubuntu.com/ubuntu artful/main amd64 libtxc-dxtn-s2tc amd64 1.0+git20151227-2 [48.4 kB]
# Fetched 20.7 MB in 0s (55.3 MB/s)
# Selecting previously unselected package libxshmfence1:amd64.
# (Reading database ... 18396 files and directories currently installed.)
# Preparing to unpack .../00-libxshmfence1_1.2-1_amd64.deb ...
# Unpacking libxshmfence1:amd64 (1.2-1) ...
# Selecting previously unselected package libxxf86vm1:amd64.
# Preparing to unpack .../01-libxxf86vm1_1%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86vm1:amd64 (1:1.1.4-1) ...
# Selecting previously unselected package libelf1:amd64.
# Preparing to unpack .../02-libelf1_0.170-0.1_amd64.deb ...
# Unpacking libelf1:amd64 (0.170-0.1) ...
# Selecting previously unselected package libdrm-common.
# Preparing to unpack .../03-libdrm-common_2.4.83-1_all.deb ...
# Unpacking libdrm-common (2.4.83-1) ...
# Selecting previously unselected package libdrm2:amd64.
# Preparing to unpack .../04-libdrm2_2.4.83-1_amd64.deb ...
# Unpacking libdrm2:amd64 (2.4.83-1) ...
# Selecting previously unselected package libglapi-mesa:amd64.
# Preparing to unpack .../05-libglapi-mesa_17.2.8-0ubuntu0~17.10.1_amd64.deb ...
# Unpacking libglapi-mesa:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Selecting previously unselected package libx11-xcb1:amd64.
# Preparing to unpack .../06-libx11-xcb1_2%3a1.6.4-3_amd64.deb ...
# Unpacking libx11-xcb1:amd64 (2:1.6.4-3) ...
# Selecting previously unselected package libxcb-dri2-0:amd64.
# Preparing to unpack .../07-libxcb-dri2-0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-dri2-0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-dri3-0:amd64.
# Preparing to unpack .../08-libxcb-dri3-0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-dri3-0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-glx0:amd64.
# Preparing to unpack .../09-libxcb-glx0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-glx0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-present0:amd64.
# Preparing to unpack .../10-libxcb-present0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-present0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-sync1:amd64.
# Preparing to unpack .../11-libxcb-sync1_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-sync1:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxdamage1:amd64.
# Preparing to unpack .../12-libxdamage1_1%3a1.1.4-3_amd64.deb ...
# Unpacking libxdamage1:amd64 (1:1.1.4-3) ...
# Selecting previously unselected package libxfixes3:amd64.
# Preparing to unpack .../13-libxfixes3_1%3a5.0.3-1_amd64.deb ...
# Unpacking libxfixes3:amd64 (1:5.0.3-1) ...
# Selecting previously unselected package libdrm-amdgpu1:amd64.
# Preparing to unpack .../14-libdrm-amdgpu1_2.4.83-1_amd64.deb ...
# Unpacking libdrm-amdgpu1:amd64 (2.4.83-1) ...
# Selecting previously unselected package libpciaccess0:amd64.
# Preparing to unpack .../15-libpciaccess0_0.13.4-1ubuntu1_amd64.deb ...
# Unpacking libpciaccess0:amd64 (0.13.4-1ubuntu1) ...
# Selecting previously unselected package libdrm-intel1:amd64.
# Preparing to unpack .../16-libdrm-intel1_2.4.83-1_amd64.deb ...
# Unpacking libdrm-intel1:amd64 (2.4.83-1) ...
# Selecting previously unselected package libdrm-nouveau2:amd64.
# Preparing to unpack .../17-libdrm-nouveau2_2.4.83-1_amd64.deb ...
# Unpacking libdrm-nouveau2:amd64 (2.4.83-1) ...
# Selecting previously unselected package libdrm-radeon1:amd64.
# Preparing to unpack .../18-libdrm-radeon1_2.4.83-1_amd64.deb ...
# Unpacking libdrm-radeon1:amd64 (2.4.83-1) ...
# Selecting previously unselected package libllvm5.0:amd64.
# Preparing to unpack .../19-libllvm5.0_1%3a5.0-3_amd64.deb ...
# Unpacking libllvm5.0:amd64 (1:5.0-3) ...
# Selecting previously unselected package libsensors4:amd64.
# Preparing to unpack .../20-libsensors4_1%3a3.4.0-4_amd64.deb ...
# Unpacking libsensors4:amd64 (1:3.4.0-4) ...
# Selecting previously unselected package libgl1-mesa-dri:amd64.
# Preparing to unpack .../21-libgl1-mesa-dri_17.2.8-0ubuntu0~17.10.1_amd64.deb ...
# Unpacking libgl1-mesa-dri:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Selecting previously unselected package libgl1-mesa-glx:amd64.
# Preparing to unpack .../22-libgl1-mesa-glx_17.2.8-0ubuntu0~17.10.1_amd64.deb ...
# Unpacking libgl1-mesa-glx:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Selecting previously unselected package libxi6:amd64.
# Preparing to unpack .../23-libxi6_2%3a1.7.9-1_amd64.deb ...
# Unpacking libxi6:amd64 (2:1.7.9-1) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../24-freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../25-libglu1-mesa_9.0.0-2.1build1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.0-2.1build1) ...
# Selecting previously unselected package python-opengl.
# Preparing to unpack .../26-python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Selecting previously unselected package libtxc-dxtn-s2tc:amd64.
# Preparing to unpack .../27-libtxc-dxtn-s2tc_1.0+git20151227-2_amd64.deb ...
# Unpacking libtxc-dxtn-s2tc:amd64 (1.0+git20151227-2) ...
# Setting up libxi6:amd64 (2:1.7.9-1) ...
# Setting up libxcb-present0:amd64 (1.12-1ubuntu1) ...
# Setting up libxcb-dri2-0:amd64 (1.12-1ubuntu1) ...
# Setting up libxcb-dri3-0:amd64 (1.12-1ubuntu1) ...
# Setting up libxcb-glx0:amd64 (1.12-1ubuntu1) ...
# Setting up libxdamage1:amd64 (1:1.1.4-3) ...
# Setting up libxfixes3:amd64 (1:5.0.3-1) ...
# Setting up libelf1:amd64 (0.170-0.1) ...
# Setting up libxshmfence1:amd64 (1.2-1) ...
# Setting up libllvm5.0:amd64 (1:5.0-3) ...
# Setting up libtxc-dxtn-s2tc:amd64 (1.0+git20151227-2) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/s2tc/libtxc_dxtn.so to provide /usr/lib/x86_64-linux-gnu/libtxc_dxtn.so (libtxc-dxtn-x86_64-linux-gnu) in auto mode
# Setting up libglapi-mesa:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libdrm-common (2.4.83-1) ...
# Setting up libxcb-sync1:amd64 (1.12-1ubuntu1) ...
# Setting up libx11-xcb1:amd64 (2:1.6.4-3) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up libpciaccess0:amd64 (0.13.4-1ubuntu1) ...
# Setting up libsensors4:amd64 (1:3.4.0-4) ...
# Setting up libxxf86vm1:amd64 (1:1.1.4-1) ...
# Setting up libdrm2:amd64 (2.4.83-1) ...
# Setting up libdrm-intel1:amd64 (2.4.83-1) ...
# Setting up libdrm-radeon1:amd64 (2.4.83-1) ...
# Setting up libdrm-nouveau2:amd64 (2.4.83-1) ...
# Setting up libdrm-amdgpu1:amd64 (2.4.83-1) ...
# Setting up libgl1-mesa-dri:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libgl1-mesa-glx:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/mesa/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_GL.conf (x86_64-linux-gnu_gl_conf) in auto mode
# Setting up libglu1-mesa:amd64 (9.0.0-2.1build1) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...

# %%
# !apt install xvfb -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libfontenc1 libpixman-1-0 libxaw7 libxfont1 libxfont2 libxkbfile1 libxmu6
#   libxmuu1 libxpm4 libxt6 x11-xkb-utils xauth xfonts-base xfonts-encodings
#   xfonts-utils xkb-data xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libpixman-1-0 libxaw7 libxfont1 libxfont2 libxkbfile1 libxmu6
#   libxmuu1 libxpm4 libxt6 x11-xkb-utils xauth xfonts-base xfonts-encodings
#   xfonts-utils xkb-data xserver-common xvfb
# 0 upgraded, 18 newly installed, 0 to remove and 7 not upgraded.
# Need to get 8,782 kB of archives.
# After this operation, 17.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful/main amd64 xkb-data all 2.19-1.1ubuntu1 [312 kB]
# Get:2 http://archive.ubuntu.com/ubuntu artful/main amd64 libxmuu1 amd64 2:1.1.2-2 [9,674 B]
# Get:3 http://archive.ubuntu.com/ubuntu artful/main amd64 xauth amd64 1:1.0.9-1ubuntu2 [22.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu artful/main amd64 libfontenc1 amd64 1:1.1.3-1 [13.9 kB]
# Get:5 http://archive.ubuntu.com/ubuntu artful/main amd64 libpixman-1-0 amd64 0.34.0-1 [230 kB]
# Get:6 http://archive.ubuntu.com/ubuntu artful/main amd64 libxt6 amd64 1:1.1.5-1 [160 kB]
# Get:7 http://archive.ubuntu.com/ubuntu artful/main amd64 libxmu6 amd64 2:1.1.2-2 [46.0 kB]
# Get:8 http://archive.ubuntu.com/ubuntu artful/main amd64 libxpm4 amd64 1:3.5.12-1 [34.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu artful/main amd64 libxaw7 amd64 2:1.0.13-1 [173 kB]
# Get:10 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libxfont1 amd64 1:1.5.2-4ubuntu1.1 [94.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libxfont2 amd64 1:2.0.1-3ubuntu1.1 [91.6 kB]
# Get:12 http://archive.ubuntu.com/ubuntu artful/main amd64 libxkbfile1 amd64 1:1.0.9-2 [64.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu artful/main amd64 x11-xkb-utils amd64 7.7+3 [158 kB]
# Get:14 http://archive.ubuntu.com/ubuntu artful/main amd64 xfonts-encodings all 1:1.0.4-2 [573 kB]
# Get:15 http://archive.ubuntu.com/ubuntu artful/main amd64 xfonts-utils amd64 1:7.7+4 [75.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu artful/main amd64 xfonts-base all 1:1.0.4+nmu1 [5,914 kB]
# Get:17 http://archive.ubuntu.com/ubuntu artful/main amd64 xserver-common all 2:1.19.5-0ubuntu2 [26.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu artful/universe amd64 xvfb amd64 2:1.19.5-0ubuntu2 [783 kB]
# Fetched 8,782 kB in 0s (39.9 MB/s)
#
# 78Selecting previously unselected package xkb-data.
# (Reading database ... 20926 files and directories currently installed.)
# Preparing to unpack .../00-xkb-data_2.19-1.1ubuntu1_all.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  1%] [..........................................................] 8Unpacking xkb-data (2.19-1.1ubuntu1) ...
# 7Progress: [  2%] [#.........................................................] 87Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libxmuu1:amd64.
# Preparing to unpack .../01-libxmuu1_2%3a1.1.2-2_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libxmuu1:amd64 (2:1.1.2-2) ...
# 7Progress: [  5%] [###.......................................................] 87Progress: [  6%] [###.......................................................] 8Selecting previously unselected package xauth.
# Preparing to unpack .../02-xauth_1%3a1.0.9-1ubuntu2_amd64.deb ...
# 7Progress: [  7%] [####......................................................] 8Unpacking xauth (1:1.0.9-1ubuntu2) ...
# 7Progress: [  8%] [#####.....................................................] 87Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../03-libfontenc1_1%3a1.1.3-1_amd64.deb ...
# 7Progress: [ 10%] [######....................................................] 8Unpacking libfontenc1:amd64 (1:1.1.3-1) ...
# 7Progress: [ 12%] [#######...................................................] 87Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package libpixman-1-0:amd64.
# Preparing to unpack .../04-libpixman-1-0_0.34.0-1_amd64.deb ...
# 7Progress: [ 14%] [########..................................................] 8Unpacking libpixman-1-0:amd64 (0.34.0-1) ...
# 7Progress: [ 15%] [########..................................................] 87Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libxt6:amd64.
# Preparing to unpack .../05-libxt6_1%3a1.1.5-1_amd64.deb ...
# 7Progress: [ 17%] [##########................................................] 8Unpacking libxt6:amd64 (1:1.1.5-1) ...
# 7Progress: [ 18%] [##########................................................] 87Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libxmu6:amd64.
# Preparing to unpack .../06-libxmu6_2%3a1.1.2-2_amd64.deb ...
# 7Progress: [ 20%] [############..............................................] 8Unpacking libxmu6:amd64 (2:1.1.2-2) ...
# 7Progress: [ 21%] [############..............................................] 87Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libxpm4:amd64.
# Preparing to unpack .../07-libxpm4_1%3a3.5.12-1_amd64.deb ...
# 7Progress: [ 24%] [##############............................................] 8Unpacking libxpm4:amd64 (1:3.5.12-1) ...
# 7Progress: [ 25%] [##############............................................] 87Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libxaw7:amd64.
# Preparing to unpack .../08-libxaw7_2%3a1.0.13-1_amd64.deb ...
# 7Progress: [ 27%] [###############...........................................] 8Unpacking libxaw7:amd64 (2:1.0.13-1) ...
# 7Progress: [ 28%] [################..........................................] 87Progress: [ 29%] [#################.........................................] 8Selecting previously unselected package libxfont1:amd64.
# Preparing to unpack .../09-libxfont1_1%3a1.5.2-4ubuntu1.1_amd64.deb ...
# 7Progress: [ 30%] [#################.........................................] 8Unpacking libxfont1:amd64 (1:1.5.2-4ubuntu1.1) ...
# 7Progress: [ 31%] [##################........................................] 8
# 7Progress: [ 32%] [###################.......................................] 8Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../10-libxfont2_1%3a2.0.1-3ubuntu1.1_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libxfont2:amd64 (1:2.0.1-3ubuntu1.1) ...
# 7Progress: [ 35%] [####################......................................] 87Progress: [ 36%] [#####################.....................................] 8Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../11-libxkbfile1_1%3a1.0.9-2_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libxkbfile1:amd64 (1:1.0.9-2) ...
# 7Progress: [ 38%] [######################....................................] 87Progress: [ 39%] [######################....................................] 8Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../12-x11-xkb-utils_7.7+3_amd64.deb ...
# 7Progress: [ 40%] [#######################...................................] 8Unpacking x11-xkb-utils (7.7+3) ...
# 7Progress: [ 41%] [########################..................................] 87Progress: [ 42%] [########################..................................] 8Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../13-xfonts-encodings_1%3a1.0.4-2_all.deb ...
# 7Progress: [ 43%] [#########################.................................] 8Unpacking xfonts-encodings (1:1.0.4-2) ...
# 7Progress: [ 45%] [##########################................................] 87Progress: [ 46%] [##########################................................] 8Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../14-xfonts-utils_1%3a7.7+4_amd64.deb ...
# 7Progress: [ 47%] [###########################...............................] 8Unpacking xfonts-utils (1:7.7+4) ...
# 7Progress: [ 48%] [############################..............................] 87Progress: [ 49%] [############################..............................] 8Selecting previously unselected package xfonts-base.
# Preparing to unpack .../15-xfonts-base_1%3a1.0.4+nmu1_all.deb ...
# 7Progress: [ 50%] [#############################.............................] 8Unpacking xfonts-base (1:1.0.4+nmu1) ...
# 7Progress: [ 51%] [#############################.............................] 87Progress: [ 52%] [##############################............................] 8Selecting previously unselected package xserver-common.
# Preparing to unpack .../16-xserver-common_2%3a1.19.5-0ubuntu2_all.deb ...
# 7Progress: [ 53%] [###############################...........................] 8Unpacking xserver-common (2:1.19.5-0ubuntu2) ...
# 7Progress: [ 54%] [###############################...........................] 87Progress: [ 56%] [################################..........................] 8Selecting previously unselected package xvfb.
# Preparing to unpack .../17-xvfb_2%3a1.19.5-0ubuntu2_amd64.deb ...
# 7Progress: [ 57%] [#################################.........................] 8Unpacking xvfb (2:1.19.5-0ubuntu2) ...
# 7Progress: [ 58%] [#################################.........................] 87Progress: [ 59%] [##################################........................] 8Setting up libxkbfile1:amd64 (1:1.0.9-2) ...
# 7Progress: [ 60%] [###################################.......................] 87Progress: [ 61%] [###################################.......................] 8Setting up xkb-data (2.19-1.1ubuntu1) ...
# 7Progress: [ 62%] [####################################......................] 87Progress: [ 63%] [####################################......................] 8Setting up xfonts-encodings (1:1.0.4-2) ...
# 7Progress: [ 64%] [#####################################.....................] 87Progress: [ 65%] [######################################....................] 8Setting up libxmuu1:amd64 (2:1.1.2-2) ...
# 7Progress: [ 67%] [######################################....................] 87Progress: [ 68%] [#######################################...................] 8Setting up xauth (1:1.0.9-1ubuntu2) ...
# 7Progress: [ 69%] [########################################..................] 87Progress: [ 70%] [########################################..................] 8Setting up libpixman-1-0:amd64 (0.34.0-1) ...
# 7Progress: [ 71%] [#########################################.................] 87Progress: [ 72%] [##########################################................] 8Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up libfontenc1:amd64 (1:1.1.3-1) ...
# 7Progress: [ 73%] [##########################################................] 87Progress: [ 74%] [###########################################...............] 8Setting up libxpm4:amd64 (1:3.5.12-1) ...
# 7Progress: [ 75%] [###########################################...............] 87Progress: [ 76%] [############################################..............] 8Setting up libxt6:amd64 (1:1.1.5-1) ...
# 7Progress: [ 78%] [#############################################.............] 87Progress: [ 79%] [#############################################.............] 8Setting up libxfont2:amd64 (1:2.0.1-3ubuntu1.1) ...
# 7Progress: [ 80%] [##############################################............] 87Progress: [ 81%] [###############################################...........] 8Setting up libxfont1:amd64 (1:1.5.2-4ubuntu1.1) ...
# 7Progress: [ 82%] [###############################################...........] 87Progress: [ 83%] [################################################..........] 8Setting up libxmu6:amd64 (2:1.1.2-2) ...
# 7Progress: [ 84%] [#################################################.........] 87Progress: [ 85%] [#################################################.........] 8Setting up libxaw7:amd64 (2:1.0.13-1) ...
# 7Progress: [ 86%] [##################################################........] 87Progress: [ 87%] [##################################################........] 8Setting up x11-xkb-utils (7.7+3) ...
# 7Progress: [ 89%] [###################################################.......] 87Progress: [ 90%] [####################################################......] 8Setting up xfonts-utils (1:7.7+4) ...
# 7Progress: [ 91%] [####################################################......] 87Progress: [ 92%] [#####################################################.....] 8Setting up xfonts-base (1:1.0.4+nmu1) ...
# 7Progress: [ 93%] [######################################################....] 87Progress: [ 94%] [######################################################....] 8Setting up xserver-common (2:1.19.5-0ubuntu2) ...
# 7Progress: [ 95%] [#######################################################...] 87Progress: [ 96%] [########################################################..] 8Setting up xvfb (2:1.19.5-0ubuntu2) ...
# 7Progress: [ 97%] [########################################################..] 87Progress: [ 98%] [#########################################################.] 8Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
#
# 78

# %%
# !pip install pyvirtualdisplay
# !pip install piglet
# Out:
# Collecting pyvirtualdisplay
#   Downloading https://files.pythonhosted.org/packages/39/37/f285403a09cc261c56b6574baace1bdcf4b8c7428c8a7239cbba137bc0eb/PyVirtualDisplay-0.2.1.tar.gz
# Collecting EasyProcess (from pyvirtualdisplay)
#   Downloading https://files.pythonhosted.org/packages/0d/f1/d2de7591e7dfc164d286fa16f051e6c0cf3141825586c3b04ae7cda7ac0f/EasyProcess-0.2.3.tar.gz
# Building wheels for collected packages: pyvirtualdisplay, EasyProcess
# done
#   Stored in directory: /content/.cache/pip/wheels/d1/8c/16/1c64227974ae29c687e4cc30fd691d5c0fd40f54446dde99da
# done
#   Stored in directory: /content/.cache/pip/wheels/b4/c6/e3/c163b04029d8fccfd54b809802640c1af587a01be8d7a04e1a
# Successfully built pyvirtualdisplay EasyProcess
# Installing collected packages: EasyProcess, pyvirtualdisplay
# Successfully installed EasyProcess-0.2.3 pyvirtualdisplay-0.2.1

# %%
# !pip install piglet
# Out:
# Collecting piglet
#   Downloading https://files.pythonhosted.org/packages/86/f6/ef278239ebe525466ea51a7dd9d6d3211d197ac4b4abc76e17cdd419f69c/piglet-0.4.4.tar.gz (52kB)
#     100% |████████████████████████████████| 61kB 5.9MB/s
# Collecting Parsley (from piglet)
#   Downloading https://files.pythonhosted.org/packages/2b/d6/4fed8d65e28a970e1c5cb33ce9c7e22e3de745e1b2ae37af051ef16aea3b/Parsley-1.3-py2.py3-none-any.whl (88kB)
#     100% |████████████████████████████████| 92kB 15.1MB/s
# Collecting attrs (from piglet)
#   Downloading https://files.pythonhosted.org/packages/41/59/cedf87e91ed541be7957c501a92102f9cc6363c623a7666d69d51c78ac5b/attrs-18.1.0-py2.py3-none-any.whl
# Collecting astunparse (from piglet)
#   Downloading https://files.pythonhosted.org/packages/8b/ea/d38686f1718e307d83673d905dcffd142640a31a217e4e76d1de78f21b20/astunparse-1.5.0-py2.py3-none-any.whl
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.6/dist-packages (from piglet) (1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from astunparse->piglet) (0.31.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from astunparse->piglet) (1.11.0)
# Building wheels for collected packages: piglet
# done
#   Stored in directory: /content/.cache/pip/wheels/c7/59/a5/5bd1a35a4a4596714c4c7925a1751e7b1580b6ced363fd7969
# Successfully built piglet
# Installing collected packages: Parsley, attrs, astunparse, piglet
# Successfully installed Parsley-1.3 astunparse-1.5.0 attrs-18.1.0 piglet-0.4.4

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# <Display cmd_param=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1001'] cmd=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1001'] oserror=None return_code=None stdout="None" stderr="None" timeout_happened=False>

# %%
from __future__ import print_function, division
from IPython.core import display
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

#If you are running on a server, launch xvfb to record game videos
#Please make sure you have xvfb installed
import os
if os.environ.get("DISPLAY") is str and len(os.environ.get("DISPLAY"))!=0:
    # !bash ../xvfb start
    # %env DISPLAY=:1

# %%
"""Auxilary files for those who wanted to solve breakout with CEM or policy gradient"""
import numpy as np
import gym
from scipy.misc import imresize
from gym.core import Wrapper
from gym.spaces.box import Box

class PreprocessAtari(Wrapper):
    def __init__(self, env, height=42, width=42, color=False, crop=lambda img: img, 
                 n_frames=4, dim_order='theano', reward_scale=1,):
        """A gym wrapper that reshapes, crops and scales image into the desired shapes"""
        super(PreprocessAtari, self).__init__(env)
        assert dim_order in ('theano', 'tensorflow')
        self.img_size = (height, width)
        self.crop=crop
        self.color=color
        self.dim_order = dim_order
        self.reward_scale = reward_scale
        
        n_channels = (3 * n_frames) if color else n_frames
        obs_shape = [n_channels,height,width] if dim_order == 'theano' else [height,width,n_channels]
        self.observation_space = Box(0.0, 1.0, obs_shape)
        self.framebuffer = np.zeros(obs_shape, 'float32')
        
    def reset(self):
        """resets breakout, returns initial frames"""
        self.framebuffer = np.zeros_like(self.framebuffer)
        self.update_buffer(self.env.reset())
        return self.framebuffer
    
    def step(self,action):
        """plays breakout for 1 step, returns frame buffer"""
        new_img, reward, done, info = self.env.step(action)
        self.update_buffer(new_img)
        return self.framebuffer, reward * self.reward_scale, done, info
    
    ### image processing ###
    
    def update_buffer(self,img):
        img = self.preproc_image(img)
        offset = 3 if self.color else 1
        if self.dim_order == 'theano':
            axis = 0
            cropped_framebuffer = self.framebuffer[:-offset]
        else:
            axis = -1
            cropped_framebuffer = self.framebuffer[:,:,:-offset]
        self.framebuffer = np.concatenate([img, cropped_framebuffer], axis = axis)

    def preproc_image(self, img):
        """what happens to the observation"""
        img = self.crop(img)
        img = imresize(img, self.img_size)
        if not self.color:
            img = img.mean(-1, keepdims=True)
        if self.dim_order == 'theano':
            img = img.transpose([2,0,1]) # [h, w, c] to [c, h, w]
        img = img.astype('float32') / 255.
        return img

# %%
# !apt-get install -y python-numpy python-dev cmake zlib1g-dev libjpeg-dev xvfb libav-tools xorg-dev python-opengl libboost-all-dev libsdl2-dev swig
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# python-dev is already the newest version (2.7.14-2ubuntu1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2).
# zlib1g-dev set to manually installed.
# python-opengl is already the newest version (3.1.0+dfsg-1).
# xvfb is already the newest version (2:1.19.5-0ubuntu2).
# The following additional packages will be installed:
#   autotools-dev cmake-data dbus ffmpeg file gir1.2-glib-2.0 gir1.2-ibus-1.0
#   i965-va-driver libaacs0 libapparmor1 libarchive13 libasound2 libasound2-data
#   libasound2-dev libass9 libasyncns0 libavc1394-0 libavcodec57 libavdevice57
#   libavfilter6 libavformat57 libavresample3 libavutil55 libbdplus0 libbluray2
#   libboost-atomic-dev libboost-atomic1.62-dev libboost-atomic1.62.0
#   libboost-chrono-dev libboost-chrono1.62-dev libboost-chrono1.62.0
#   libboost-context-dev libboost-context1.62-dev libboost-context1.62.0
#   libboost-coroutine-dev libboost-coroutine1.62-dev libboost-coroutine1.62.0
#   libboost-date-time-dev libboost-date-time1.62-dev libboost-date-time1.62.0
#   libboost-dev libboost-exception-dev libboost-exception1.62-dev
#   libboost-fiber-dev libboost-fiber1.62-dev libboost-fiber1.62.0
#   libboost-filesystem-dev libboost-filesystem1.62-dev
#   libboost-filesystem1.62.0 libboost-graph-dev libboost-graph-parallel-dev
#   libboost-graph-parallel1.62-dev libboost-graph-parallel1.62.0
#   libboost-graph1.62-dev libboost-graph1.62.0 libboost-iostreams-dev
#   libboost-iostreams1.62-dev libboost-iostreams1.62.0 libboost-locale-dev
#   libboost-locale1.62-dev libboost-locale1.62.0 libboost-log-dev
#   libboost-log1.62-dev libboost-log1.62.0 libboost-math-dev
#   libboost-math1.62-dev libboost-math1.62.0 libboost-mpi-dev
#   libboost-mpi-python-dev libboost-mpi-python1.62-dev
#   libboost-mpi-python1.62.0 libboost-mpi1.62-dev libboost-mpi1.62.0
#   libboost-program-options-dev libboost-program-options1.62-dev
#   libboost-program-options1.62.0 libboost-python-dev libboost-python1.62-dev
#   libboost-python1.62.0 libboost-random-dev libboost-random1.62-dev
#   libboost-random1.62.0 libboost-regex-dev libboost-regex1.62-dev
#   libboost-regex1.62.0 libboost-serialization-dev
#   libboost-serialization1.62-dev libboost-serialization1.62.0
#   libboost-signals-dev libboost-signals1.62-dev libboost-signals1.62.0
#   libboost-system-dev libboost-system1.62-dev libboost-system1.62.0
#   libboost-test-dev libboost-test1.62-dev libboost-test1.62.0
#   libboost-thread-dev libboost-thread1.62-dev libboost-thread1.62.0
#   libboost-timer-dev libboost-timer1.62-dev libboost-timer1.62.0
#   libboost-tools-dev libboost-type-erasure-dev libboost-type-erasure1.62-dev
#   libboost-type-erasure1.62.0 libboost-wave-dev libboost-wave1.62-dev
#   libboost-wave1.62.0 libboost1.62-dev libboost1.62-tools-dev libbs2b0
#   libcaca0 libcairo2 libcapnp-0.5.3 libcdio-cdda1 libcdio-paranoia1 libcdio13
#   libchromaprint1 libcrystalhd3 libdbus-1-3 libdbus-1-dev libdc1394-22
#   libdmx-dev libdmx1 libdrm-dev libegl1-mesa libegl1-mesa-dev libfabric1
#   libfftw3-double3 libflac8 libflite1 libfontenc-dev libfribidi0 libfs-dev
#   libfs6 libgbm1 libgirepository-1.0-1 libgl1-mesa-dev libgles2-mesa
#   libgles2-mesa-dev libglib2.0-bin libglib2.0-data libglib2.0-dev
#   libglib2.0-dev-bin libglu1-mesa-dev libgme0 libgraphite2-3 libgsm1
#   libharfbuzz0b libhwloc-dev libhwloc-plugins libhwloc5 libibus-1.0-5
#   libibus-1.0-dev libibverbs-dev libibverbs1 libice-dev libiec61883-0
#   libjack-jackd2-0 libjsoncpp1 libltdl-dev libltdl7 liblzo2-2 libmagic-mgc
#   libmagic1 libmirclient-dev libmirclient9 libmircommon-dev libmircommon7
#   libmircookie-dev libmircookie2 libmircore-dev libmircore1 libmirprotobuf3
#   libmp3lame0 libmpg123-0 libnl-3-200 libnl-route-3-200 libnuma-dev libnuma1
#   libogg0 libopenal-data libopenal1 libopencv-core3.1 libopencv-imgproc3.1
#   libopenjp2-7 libopenmpi-dev libopenmpi2 libopenmpt0 libopus0
#   libpciaccess-dev libpcre16-3 libpcre3-dev libpcre32-3 libpcrecpp0v5
#   libpixman-1-dev libpostproc54 libprotobuf-dev libprotobuf-lite10
#   libprotobuf10 libpsm-infinipath1 libpulse-dev libpulse-mainloop-glib0
#   libpulse0 libraw1394-11 librdmacm1 librhash0 librubberband2v5 libsamplerate0
#   libsdl2-2.0-0 libshine3 libslang2 libsm-dev libsnappy1v5 libsndfile1
#   libsndio-dev libsndio6.1 libsoxr0 libspeex1 libssh-gcrypt-4 libswresample2
#   libswscale4 libtbb2 libtheora0 libtool libtwolame0 libudev-dev libudev1
#   libusb-1.0-0 libuv1 libva-drm1 libva-x11-1 libva1 libvdpau1 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx4 libwavpack1 libwayland-bin
#   libwayland-client0 libwayland-cursor0 libwayland-dev libwayland-egl1-mesa
#   libwayland-server0 libwebp6 libwebpmux3 libwrap0 libx11-xcb-dev libx264-148
#   libx265-130 libxaw7-dev libxcb-dri2-0-dev libxcb-dri3-dev libxcb-glx0-dev
#   libxcb-present-dev libxcb-randr0 libxcb-randr0-dev libxcb-render0
#   libxcb-render0-dev libxcb-shape0 libxcb-shape0-dev libxcb-shm0
#   libxcb-sync-dev libxcb-xfixes0 libxcb-xfixes0-dev libxcomposite-dev
#   libxcomposite1 libxcursor-dev libxcursor1 libxdamage-dev libxext-dev
#   libxfixes-dev libxfont-dev libxi-dev libxinerama-dev libxinerama1
#   libxkbcommon-dev libxkbcommon0 libxkbfile-dev libxmu-dev libxmu-headers
#   libxmuu-dev libxpm-dev libxrandr-dev libxrandr2 libxres-dev libxres1
#   libxshmfence-dev libxss-dev libxt-dev libxtst-dev libxtst6 libxv-dev libxv1
#   libxvidcore4 libxvmc-dev libxvmc1 libxxf86dga-dev libxxf86dga1
#   libxxf86vm-dev libzvbi-common libzvbi0 mesa-common-dev mesa-va-drivers
#   mesa-vdpau-drivers mir-client-platform-mesa-dev mpi-default-bin
#   mpi-default-dev ocl-icd-libopencl1 openmpi-bin openmpi-common swig3.0 tcpd
#   va-driver-all vdpau-driver-all x11proto-bigreqs-dev x11proto-composite-dev
#   x11proto-damage-dev x11proto-dmx-dev x11proto-dri2-dev x11proto-dri3-dev
#   x11proto-fixes-dev x11proto-fonts-dev x11proto-gl-dev x11proto-present-dev
#   x11proto-randr-dev x11proto-record-dev x11proto-resource-dev
#   x11proto-scrnsaver-dev x11proto-video-dev x11proto-xcmisc-dev
#   x11proto-xext-dev x11proto-xf86bigfont-dev x11proto-xf86dga-dev
#   x11proto-xf86dri-dev x11proto-xf86vidmode-dev x11proto-xinerama-dev
#   xserver-xorg-dev
# Suggested packages:
#   ninja-build default-dbus-session-bus | dbus-session-bus ffmpeg-doc lrzip
#   libasound2-plugins alsa-utils libasound2-doc libbluray-bdj libboost-doc
#   graphviz libboost1.62-doc gccxml libmpfrc++-dev libntl-dev xsltproc doxygen
#   docbook-xml docbook-xsl default-jdk fop firmware-crystalhd libfftw3-bin
#   libfftw3-dev libglib2.0-doc libhwloc-contrib-plugins libice-doc jackd2
#   libtool-doc libportaudio2 openmpi-doc opus-tools pulseaudio libraw1394-doc
#   libsm-doc sndiod speex autoconf automaken gcj-jdk libxaw-doc libxext-doc
#   libxt-doc opencl-icd python-nose python-numpy-dbg python-numpy-doc swig-doc
#   swig-examples swig3.0-examples swig3.0-doc libfglrx-amdxvba1 libvdpau-va-gl1
#   nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
# The following NEW packages will be installed:
#   autotools-dev cmake cmake-data dbus ffmpeg file gir1.2-glib-2.0
#   gir1.2-ibus-1.0 i965-va-driver libaacs0 libapparmor1 libarchive13 libasound2
#   libasound2-data libasound2-dev libass9 libasyncns0 libav-tools libavc1394-0
#   libavcodec57 libavdevice57 libavfilter6 libavformat57 libavresample3
#   libavutil55 libbdplus0 libbluray2 libboost-all-dev libboost-atomic-dev
#   libboost-atomic1.62-dev libboost-atomic1.62.0 libboost-chrono-dev
#   libboost-chrono1.62-dev libboost-chrono1.62.0 libboost-context-dev
#   libboost-context1.62-dev libboost-context1.62.0 libboost-coroutine-dev
#   libboost-coroutine1.62-dev libboost-coroutine1.62.0 libboost-date-time-dev
#   libboost-date-time1.62-dev libboost-date-time1.62.0 libboost-dev
#   libboost-exception-dev libboost-exception1.62-dev libboost-fiber-dev
#   libboost-fiber1.62-dev libboost-fiber1.62.0 libboost-filesystem-dev
#   libboost-filesystem1.62-dev libboost-filesystem1.62.0 libboost-graph-dev
#   libboost-graph-parallel-dev libboost-graph-parallel1.62-dev
#   libboost-graph-parallel1.62.0 libboost-graph1.62-dev libboost-graph1.62.0
#   libboost-iostreams-dev libboost-iostreams1.62-dev libboost-iostreams1.62.0
#   libboost-locale-dev libboost-locale1.62-dev libboost-locale1.62.0
#   libboost-log-dev libboost-log1.62-dev libboost-log1.62.0 libboost-math-dev
#   libboost-math1.62-dev libboost-math1.62.0 libboost-mpi-dev
#   libboost-mpi-python-dev libboost-mpi-python1.62-dev
#   libboost-mpi-python1.62.0 libboost-mpi1.62-dev libboost-mpi1.62.0
#   libboost-program-options-dev libboost-program-options1.62-dev
#   libboost-program-options1.62.0 libboost-python-dev libboost-python1.62-dev
#   libboost-python1.62.0 libboost-random-dev libboost-random1.62-dev
#   libboost-random1.62.0 libboost-regex-dev libboost-regex1.62-dev
#   libboost-regex1.62.0 libboost-serialization-dev
#   libboost-serialization1.62-dev libboost-serialization1.62.0
#   libboost-signals-dev libboost-signals1.62-dev libboost-signals1.62.0
#   libboost-system-dev libboost-system1.62-dev libboost-system1.62.0
#   libboost-test-dev libboost-test1.62-dev libboost-test1.62.0
#   libboost-thread-dev libboost-thread1.62-dev libboost-thread1.62.0
#   libboost-timer-dev libboost-timer1.62-dev libboost-timer1.62.0
#   libboost-tools-dev libboost-type-erasure-dev libboost-type-erasure1.62-dev
#   libboost-type-erasure1.62.0 libboost-wave-dev libboost-wave1.62-dev
#   libboost-wave1.62.0 libboost1.62-dev libboost1.62-tools-dev libbs2b0
#   libcaca0 libcairo2 libcapnp-0.5.3 libcdio-cdda1 libcdio-paranoia1 libcdio13
#   libchromaprint1 libcrystalhd3 libdbus-1-3 libdbus-1-dev libdc1394-22
#   libdmx-dev libdmx1 libdrm-dev libegl1-mesa libegl1-mesa-dev libfabric1
#   libfftw3-double3 libflac8 libflite1 libfontenc-dev libfribidi0 libfs-dev
#   libfs6 libgbm1 libgirepository-1.0-1 libgl1-mesa-dev libgles2-mesa
#   libgles2-mesa-dev libglib2.0-bin libglib2.0-data libglib2.0-dev
#   libglib2.0-dev-bin libglu1-mesa-dev libgme0 libgraphite2-3 libgsm1
#   libharfbuzz0b libhwloc-dev libhwloc-plugins libhwloc5 libibus-1.0-5
#   libibus-1.0-dev libibverbs-dev libibverbs1 libice-dev libiec61883-0
#   libjack-jackd2-0 libjsoncpp1 libltdl-dev libltdl7 liblzo2-2 libmagic-mgc
#   libmagic1 libmirclient-dev libmirclient9 libmircommon-dev libmircommon7
#   libmircookie-dev libmircookie2 libmircore-dev libmircore1 libmirprotobuf3
#   libmp3lame0 libmpg123-0 libnl-3-200 libnl-route-3-200 libnuma-dev libnuma1
#   libogg0 libopenal-data libopenal1 libopencv-core3.1 libopencv-imgproc3.1
#   libopenjp2-7 libopenmpi-dev libopenmpi2 libopenmpt0 libopus0
#   libpciaccess-dev libpcre16-3 libpcre3-dev libpcre32-3 libpcrecpp0v5
#   libpixman-1-dev libpostproc54 libprotobuf-dev libprotobuf-lite10
#   libprotobuf10 libpsm-infinipath1 libpulse-dev libpulse-mainloop-glib0
#   libpulse0 libraw1394-11 librdmacm1 librhash0 librubberband2v5 libsamplerate0
#   libsdl2-2.0-0 libsdl2-dev libshine3 libslang2 libsm-dev libsnappy1v5
#   libsndfile1 libsndio-dev libsndio6.1 libsoxr0 libspeex1 libssh-gcrypt-4
#   libswresample2 libswscale4 libtbb2 libtheora0 libtool libtwolame0
#   libudev-dev libusb-1.0-0 libuv1 libva-drm1 libva-x11-1 libva1 libvdpau1
#   libvorbis0a libvorbisenc2 libvorbisfile3 libvpx4 libwavpack1 libwayland-bin
#   libwayland-client0 libwayland-cursor0 libwayland-dev libwayland-egl1-mesa
#   libwayland-server0 libwebp6 libwebpmux3 libwrap0 libx11-xcb-dev libx264-148
#   libx265-130 libxaw7-dev libxcb-dri2-0-dev libxcb-dri3-dev libxcb-glx0-dev
#   libxcb-present-dev libxcb-randr0 libxcb-randr0-dev libxcb-render0
#   libxcb-render0-dev libxcb-shape0 libxcb-shape0-dev libxcb-shm0
#   libxcb-sync-dev libxcb-xfixes0 libxcb-xfixes0-dev libxcomposite-dev
#   libxcomposite1 libxcursor-dev libxcursor1 libxdamage-dev libxext-dev
#   libxfixes-dev libxfont-dev libxi-dev libxinerama-dev libxinerama1
#   libxkbcommon-dev libxkbcommon0 libxkbfile-dev libxmu-dev libxmu-headers
#   libxmuu-dev libxpm-dev libxrandr-dev libxrandr2 libxres-dev libxres1
#   libxshmfence-dev libxss-dev libxt-dev libxtst-dev libxtst6 libxv-dev libxv1
#   libxvidcore4 libxvmc-dev libxvmc1 libxxf86dga-dev libxxf86dga1
#   libxxf86vm-dev libzvbi-common libzvbi0 mesa-common-dev mesa-va-drivers
#   mesa-vdpau-drivers mir-client-platform-mesa-dev mpi-default-bin
#   mpi-default-dev ocl-icd-libopencl1 openmpi-bin openmpi-common python-numpy
#   swig swig3.0 tcpd va-driver-all vdpau-driver-all x11proto-bigreqs-dev
#   x11proto-composite-dev x11proto-damage-dev x11proto-dmx-dev
#   x11proto-dri2-dev x11proto-dri3-dev x11proto-fixes-dev x11proto-fonts-dev
#   x11proto-gl-dev x11proto-present-dev x11proto-randr-dev x11proto-record-dev
#   x11proto-resource-dev x11proto-scrnsaver-dev x11proto-video-dev
#   x11proto-xcmisc-dev x11proto-xext-dev x11proto-xf86bigfont-dev
#   x11proto-xf86dga-dev x11proto-xf86dri-dev x11proto-xf86vidmode-dev
#   x11proto-xinerama-dev xorg-dev xserver-xorg-dev
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 347 newly installed, 0 to remove and 6 not upgraded.
# Need to get 76.8 MB of archives.
# After this operation, 449 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful/main amd64 cmake-data all 3.9.1-1 [1,276 kB]
# Get:2 http://archive.ubuntu.com/ubuntu artful/main amd64 liblzo2-2 amd64 2.08-1.2 [48.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu artful/main amd64 libarchive13 amd64 3.2.2-3.1 [289 kB]
# Get:4 http://archive.ubuntu.com/ubuntu artful/main amd64 libjsoncpp1 amd64 1.7.4-3 [73.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu artful/main amd64 librhash0 amd64 1.3.4-3 [77.0 kB]
# Get:6 http://archive.ubuntu.com/ubuntu artful/main amd64 libuv1 amd64 1.9.1-3 [58.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu artful/main amd64 cmake amd64 3.9.1-1 [3,107 kB]
# Get:8 http://archive.ubuntu.com/ubuntu artful/main amd64 libdmx1 amd64 1:1.1.3-1 [10.4 kB]
# Get:9 http://archive.ubuntu.com/ubuntu artful/universe amd64 libgsm1 amd64 1.0.13-4 [27.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu artful/main amd64 libogg0 amd64 1.3.2-1 [17.2 kB]
# Get:11 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libudev1 amd64 234-2ubuntu12.4 [52.4 kB]
# Get:12 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libudev-dev amd64 234-2ubuntu12.4 [19.0 kB]
# Get:13 http://archive.ubuntu.com/ubuntu artful/main amd64 libxinerama1 amd64 2:1.1.3-1 [7,908 B]
# Get:14 http://archive.ubuntu.com/ubuntu artful/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:15 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libapparmor1 amd64 2.11.0-2ubuntu17.1 [28.9 kB]
# Get:16 http://archive.ubuntu.com/ubuntu artful/main amd64 libdbus-1-3 amd64 1.10.22-1ubuntu1 [165 kB]
# Get:17 http://archive.ubuntu.com/ubuntu artful/main amd64 dbus amd64 1.10.22-1ubuntu1 [144 kB]
# Get:18 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libmagic-mgc amd64 1:5.32-1ubuntu0.1 [184 kB]
# Get:19 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libmagic1 amd64 1:5.32-1ubuntu0.1 [68.4 kB]
# Get:20 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 file amd64 1:5.32-1ubuntu0.1 [22.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu artful/main amd64 libfribidi0 amd64 0.19.7-1 [25.1 kB]
# Get:22 http://archive.ubuntu.com/ubuntu artful/main amd64 libglib2.0-data all 2.54.1-1ubuntu1 [4,250 B]
# Get:23 http://archive.ubuntu.com/ubuntu artful/main amd64 libslang2 amd64 2.3.1-5ubuntu1 [422 kB]
# Get:24 http://archive.ubuntu.com/ubuntu artful/main amd64 libgirepository-1.0-1 amd64 1.54.1-1 [82.1 kB]
# Get:25 http://archive.ubuntu.com/ubuntu artful/main amd64 gir1.2-glib-2.0 amd64 1.54.1-1 [131 kB]
# Get:26 http://archive.ubuntu.com/ubuntu artful/main amd64 libnuma1 amd64 2.0.11-2.1 [21.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu artful/main amd64 libusb-1.0-0 amd64 2:1.0.21-2 [43.3 kB]
# Get:28 http://archive.ubuntu.com/ubuntu artful/main amd64 autotools-dev all 20161112.1 [39.5 kB]
# Get:29 http://archive.ubuntu.com/ubuntu artful/universe amd64 libva-drm1 amd64 1.8.3-2 [7,858 B]
# Get:30 http://archive.ubuntu.com/ubuntu artful/universe amd64 libva1 amd64 1.8.3-2 [44.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu artful/universe amd64 libva-x11-1 amd64 1.8.3-2 [11.4 kB]
# Get:32 http://archive.ubuntu.com/ubuntu artful/main amd64 libvdpau1 amd64 1.1.1-3ubuntu1 [25.5 kB]
# Get:33 http://archive.ubuntu.com/ubuntu artful/universe amd64 libavutil55 amd64 7:3.3.4-2 [183 kB]
# Get:34 http://archive.ubuntu.com/ubuntu artful/universe amd64 libcrystalhd3 amd64 1:0.0~git20110715.fdd2f19-12 [45.8 kB]
# Get:35 http://archive.ubuntu.com/ubuntu artful/universe amd64 libmp3lame0 amd64 3.99.5+repack1-9build1 [127 kB]
# Get:36 http://archive.ubuntu.com/ubuntu artful/universe amd64 libopenjp2-7 amd64 2.2.0-1 [133 kB]
# Get:37 http://archive.ubuntu.com/ubuntu artful/main amd64 libopus0 amd64 1.1.2-1ubuntu1 [159 kB]
# Get:38 http://archive.ubuntu.com/ubuntu artful/universe amd64 libshine3 amd64 3.1.1-1 [22.9 kB]
# Get:39 http://archive.ubuntu.com/ubuntu artful/main amd64 libsnappy1v5 amd64 1.1.6-4 [16.0 kB]
# Get:40 http://archive.ubuntu.com/ubuntu artful/main amd64 libspeex1 amd64 1.2~rc1.2-1ubuntu1 [51.3 kB]
# Get:41 http://archive.ubuntu.com/ubuntu artful/universe amd64 libsoxr0 amd64 0.1.2-2 [64.7 kB]
# Get:42 http://archive.ubuntu.com/ubuntu artful/universe amd64 libswresample2 amd64 7:3.3.4-2 [55.4 kB]
# Get:43 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-render0 amd64 1.12-1ubuntu1 [14.8 kB]
# Get:44 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-shm0 amd64 1.12-1ubuntu1 [5,482 B]
# Get:45 http://archive.ubuntu.com/ubuntu artful/main amd64 libcairo2 amd64 1.14.10-1ubuntu1 [558 kB]
# 10% [45 libcairo2 0 B/558 kB 0%]
# Get:46 http://archive.ubuntu.com/ubuntu artful/main amd64 libtheora0 amd64 1.1.1+dfsg.1-14 [170 kB]
# Get:47 http://archive.ubuntu.com/ubuntu artful/universe amd64 libtwolame0 amd64 0.3.13-2 [46.1 kB]
# Get:48 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libvorbis0a amd64 1.3.5-4ubuntu0.2 [86.5 kB]
# Get:49 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libvorbisenc2 amd64 1.3.5-4ubuntu0.2 [70.6 kB]
# Get:50 http://archive.ubuntu.com/ubuntu artful/main amd64 libvpx4 amd64 1.6.1-3 [763 kB]
# Get:51 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwavpack1 amd64 5.1.0-2ubuntu0.3 [76.3 kB]
# Get:52 http://archive.ubuntu.com/ubuntu artful/main amd64 libwebp6 amd64 0.6.0-3 [181 kB]
# Get:53 http://archive.ubuntu.com/ubuntu artful/main amd64 libwebpmux3 amd64 0.6.0-3 [20.0 kB]
# Get:54 http://archive.ubuntu.com/ubuntu artful/universe amd64 libx264-148 amd64 2:0.148.2795+gitaaa9aa8-1 [604 kB]
# Get:55 http://archive.ubuntu.com/ubuntu artful/universe amd64 libx265-130 amd64 2.5-2 [1,044 kB]
# Get:56 http://archive.ubuntu.com/ubuntu artful/universe amd64 libxvidcore4 amd64 2:1.3.4-1 [206 kB]
# Get:57 http://archive.ubuntu.com/ubuntu artful/universe amd64 libzvbi-common all 0.2.35-13 [32.1 kB]
# Get:58 http://archive.ubuntu.com/ubuntu artful/universe amd64 libzvbi0 amd64 0.2.35-13 [235 kB]
# Get:59 http://archive.ubuntu.com/ubuntu artful/universe amd64 libavcodec57 amd64 7:3.3.4-2 [4,513 kB]
# Get:60 http://archive.ubuntu.com/ubuntu artful/main amd64 libasound2-data all 1.1.3-5 [36.1 kB]
# Get:61 http://archive.ubuntu.com/ubuntu artful/main amd64 libasound2 amd64 1.1.3-5 [357 kB]
# Get:62 http://archive.ubuntu.com/ubuntu artful/main amd64 libraw1394-11 amd64 2.1.2-1 [30.7 kB]
# Get:63 http://archive.ubuntu.com/ubuntu artful/main amd64 libavc1394-0 amd64 0.5.4-4 [16.1 kB]
# Get:64 http://archive.ubuntu.com/ubuntu artful/main amd64 libgraphite2-3 amd64 1.3.10-2 [78.3 kB]
# Get:65 http://archive.ubuntu.com/ubuntu artful/main amd64 libharfbuzz0b amd64 1.4.2-1 [211 kB]
# Get:66 http://archive.ubuntu.com/ubuntu artful/universe amd64 libass9 amd64 1:0.13.7-2 [83.7 kB]
# Get:67 http://archive.ubuntu.com/ubuntu artful/universe amd64 libbluray2 amd64 1:1.0.1.deb1-2 [136 kB]
# Get:68 http://archive.ubuntu.com/ubuntu artful/universe amd64 libchromaprint1 amd64 1.4.2-1 [36.8 kB]
# Get:69 http://archive.ubuntu.com/ubuntu artful/universe amd64 libgme0 amd64 0.6.1-1 [122 kB]
# Get:70 http://archive.ubuntu.com/ubuntu artful/universe amd64 libmpg123-0 amd64 1.25.6-1 [125 kB]
# Get:71 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libvorbisfile3 amd64 1.3.5-4ubuntu0.2 [15.9 kB]
# Get:72 http://archive.ubuntu.com/ubuntu artful/universe amd64 libopenmpt0 amd64 0.2.8760~beta27-1 [474 kB]
# Get:73 http://archive.ubuntu.com/ubuntu artful/main amd64 libssh-gcrypt-4 amd64 0.7.5-1 [162 kB]
# Get:74 http://archive.ubuntu.com/ubuntu artful/universe amd64 libavformat57 amd64 7:3.3.4-2 [924 kB]
# Get:75 http://archive.ubuntu.com/ubuntu artful/universe amd64 libavresample3 amd64 7:3.3.4-2 [52.7 kB]
# Get:76 http://archive.ubuntu.com/ubuntu artful/universe amd64 libbs2b0 amd64 3.1.0+dfsg-2.2 [10.5 kB]
# Get:77 http://archive.ubuntu.com/ubuntu artful/universe amd64 libflite1 amd64 2.0.0-release-4 [12.9 MB]
# Get:78 http://archive.ubuntu.com/ubuntu artful/universe amd64 libtbb2 amd64 2017~U7-6 [112 kB]
# Get:79 http://archive.ubuntu.com/ubuntu artful/universe amd64 libopencv-core3.1 amd64 3.1.0+dfsg1-1~exp1ubuntu3 [698 kB]
# Get:80 http://archive.ubuntu.com/ubuntu artful/universe amd64 libopencv-imgproc3.1 amd64 3.1.0+dfsg1-1~exp1ubuntu3 [778 kB]
# Get:81 http://archive.ubuntu.com/ubuntu artful/universe amd64 libpostproc54 amd64 7:3.3.4-2 [50.5 kB]
# Get:82 http://archive.ubuntu.com/ubuntu artful/main amd64 libfftw3-double3 amd64 3.3.6p2-1 [727 kB]
# Get:83 http://archive.ubuntu.com/ubuntu artful/main amd64 libsamplerate0 amd64 0.1.9-1 [938 kB]
# Get:84 http://archive.ubuntu.com/ubuntu artful/universe amd64 librubberband2v5 amd64 1.8.1-6ubuntu2 [85.3 kB]
# Get:85 http://archive.ubuntu.com/ubuntu artful/universe amd64 libswscale4 amd64 7:3.3.4-2 [150 kB]
# Get:86 http://archive.ubuntu.com/ubuntu artful/universe amd64 libavfilter6 amd64 7:3.3.4-2 [812 kB]
# Get:87 http://archive.ubuntu.com/ubuntu artful/main amd64 libcaca0 amd64 0.99.beta19-2build2~gcc5.2 [202 kB]
# Get:88 http://archive.ubuntu.com/ubuntu artful/main amd64 libcdio13 amd64 0.83-4.2ubuntu1 [53.0 kB]
# Get:89 http://archive.ubuntu.com/ubuntu artful/main amd64 libcdio-cdda1 amd64 0.83-4.2ubuntu1 [15.7 kB]
# Get:90 http://archive.ubuntu.com/ubuntu artful/main amd64 libcdio-paranoia1 amd64 0.83-4.2ubuntu1 [15.4 kB]
# Get:91 http://archive.ubuntu.com/ubuntu artful/universe amd64 libdc1394-22 amd64 2.2.5-1 [77.5 kB]
# Get:92 http://archive.ubuntu.com/ubuntu artful/main amd64 libiec61883-0 amd64 1.2.0-2 [23.5 kB]
# Get:93 http://archive.ubuntu.com/ubuntu artful/main amd64 libjack-jackd2-0 amd64 1.9.10+20150825git1ed50c92~dfsg-5ubuntu1 [256 kB]
# Get:94 http://archive.ubuntu.com/ubuntu artful/universe amd64 libopenal-data all 1:1.17.2-4 [101 kB]
# Get:95 http://archive.ubuntu.com/ubuntu artful/universe amd64 libsndio6.1 amd64 1.1.0-3 [23.4 kB]
# Get:96 http://archive.ubuntu.com/ubuntu artful/universe amd64 libopenal1 amd64 1:1.17.2-4 [207 kB]
# Get:97 http://archive.ubuntu.com/ubuntu artful/main amd64 libasyncns0 amd64 0.8-6 [12.1 kB]
# Get:98 http://archive.ubuntu.com/ubuntu artful/main amd64 libflac8 amd64 1.3.2-1 [213 kB]
# Get:99 http://archive.ubuntu.com/ubuntu artful/main amd64 libsndfile1 amd64 1.0.28-4 [169 kB]
# Get:100 http://archive.ubuntu.com/ubuntu artful/main amd64 libwrap0 amd64 7.6.q-26 [46.1 kB]
# Get:101 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libpulse0 amd64 1:10.0-2ubuntu3.1 [265 kB]
# Get:102 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-client0 amd64 1.14.0-1ubuntu0.1 [22.5 kB]
# Get:103 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-cursor0 amd64 1.14.0-1ubuntu0.1 [9,890 B]
# Get:104 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-server0 amd64 1.14.0-1ubuntu0.1 [28.5 kB]
# Get:105 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgbm1 amd64 17.2.8-0ubuntu0~17.10.1 [24.4 kB]
# Get:106 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-system1.62.0 amd64 1.62.0+dfsg-4build3 [9,212 B]
# Get:107 http://archive.ubuntu.com/ubuntu artful/main amd64 libcapnp-0.5.3 amd64 0.5.3-2ubuntu2 [569 kB]
# Get:108 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-filesystem1.62.0 amd64 1.62.0+dfsg-4build3 [38.6 kB]
# Get:109 http://archive.ubuntu.com/ubuntu artful/main amd64 libmircore1 amd64 0.28.0+17.10.20171011.1-0ubuntu1 [31.5 kB]
# Get:110 http://archive.ubuntu.com/ubuntu artful/main amd64 libmircommon7 amd64 0.28.0+17.10.20171011.1-0ubuntu1 [73.2 kB]
# Get:111 http://archive.ubuntu.com/ubuntu artful/main amd64 libprotobuf-lite10 amd64 3.0.0-9ubuntu5 [97.1 kB]
# Get:112 http://archive.ubuntu.com/ubuntu artful/main amd64 libmirprotobuf3 amd64 0.28.0+17.10.20171011.1-0ubuntu1 [131 kB]
# Get:113 http://archive.ubuntu.com/ubuntu artful/main amd64 libxkbcommon0 amd64 0.7.1-2 [97.2 kB]
# Get:114 http://archive.ubuntu.com/ubuntu artful/main amd64 libmirclient9 amd64 0.28.0+17.10.20171011.1-0ubuntu1 [199 kB]
# Get:115 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-xfixes0 amd64 1.12-1ubuntu1 [9,292 B]
# Get:116 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libegl1-mesa amd64 17.2.8-0ubuntu0~17.10.1 [85.3 kB]
# Get:117 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-egl1-mesa amd64 17.2.8-0ubuntu0~17.10.1 [5,778 B]
# Get:118 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libxcursor1 amd64 1:1.1.14-3ubuntu0.1 [19.8 kB]
# Get:119 http://archive.ubuntu.com/ubuntu artful/main amd64 libxrandr2 amd64 2:1.5.1-1 [18.1 kB]
# Get:120 http://archive.ubuntu.com/ubuntu artful/universe amd64 libsdl2-2.0-0 amd64 2.0.6+dfsg1-3ubuntu1 [346 kB]
# Get:121 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-shape0 amd64 1.12-1ubuntu1 [5,864 B]
# Get:122 http://archive.ubuntu.com/ubuntu artful/main amd64 libxv1 amd64 2:1.0.11-1 [10.7 kB]
# Get:123 http://archive.ubuntu.com/ubuntu artful/universe amd64 libavdevice57 amd64 7:3.3.4-2 [73.7 kB]
# Get:124 http://archive.ubuntu.com/ubuntu artful/universe amd64 ffmpeg amd64 7:3.3.4-2 [1,524 kB]
# Get:125 http://archive.ubuntu.com/ubuntu artful/main amd64 libibus-1.0-5 amd64 1.5.14-2ubuntu1 [129 kB]
# Get:126 http://archive.ubuntu.com/ubuntu artful/main amd64 gir1.2-ibus-1.0 amd64 1.5.14-2ubuntu1 [66.0 kB]
# Get:127 http://archive.ubuntu.com/ubuntu artful/universe amd64 libaacs0 amd64 0.9.0-1 [51.4 kB]
# 50% [Working]
# Get:128 http://archive.ubuntu.com/ubuntu artful/main amd64 libasound2-dev amd64 1.1.3-5 [123 kB]
# Get:129 http://archive.ubuntu.com/ubuntu artful/universe amd64 libbdplus0 amd64 0.1.2-2 [46.6 kB]
# Get:130 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost1.62-dev amd64 1.62.0+dfsg-4build3 [7,030 kB]
# Get:131 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-dev amd64 1.62.0.1 [3,074 B]
# Get:132 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost1.62-tools-dev amd64 1.62.0+dfsg-4build3 [1,204 kB]
# Get:133 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-tools-dev amd64 1.62.0.1 [3,038 B]
# Get:134 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-atomic1.62.0 amd64 1.62.0+dfsg-4build3 [7,148 B]
# Get:135 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-atomic1.62-dev amd64 1.62.0+dfsg-4build3 [5,076 B]
# Get:136 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-atomic-dev amd64 1.62.0.1 [3,172 B]
# Get:137 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-chrono1.62.0 amd64 1.62.0+dfsg-4build3 [11.8 kB]
# Get:138 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-chrono1.62-dev amd64 1.62.0+dfsg-4build3 [12.1 kB]
# Get:139 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-chrono-dev amd64 1.62.0.1 [3,498 B]
# Get:140 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-context1.62.0 amd64 1.62.0+dfsg-4build3 [8,220 B]
# Get:141 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-context1.62-dev amd64 1.62.0+dfsg-4build3 [6,488 B]
# Get:142 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-context-dev amd64 1.62.0.1 [3,062 B]
# Get:143 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-thread1.62.0 amd64 1.62.0+dfsg-4build3 [47.3 kB]
# Get:144 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-coroutine1.62.0 amd64 1.62.0+dfsg-4build3 [19.7 kB]
# Get:145 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-coroutine1.62-dev amd64 1.62.0+dfsg-4build3 [20.2 kB]
# Get:146 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-coroutine-dev amd64 1.62.0.1 [3,126 B]
# Get:147 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-date-time1.62.0 amd64 1.62.0+dfsg-4build3 [19.8 kB]
# Get:148 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-serialization1.62.0 amd64 1.62.0+dfsg-4build3 [101 kB]
# Get:149 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-serialization1.62-dev amd64 1.62.0+dfsg-4build3 [139 kB]
# Get:150 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-date-time1.62-dev amd64 1.62.0+dfsg-4build3 [25.8 kB]
# Get:151 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-date-time-dev amd64 1.62.0.1 [2,876 B]
# Get:152 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-exception1.62-dev amd64 1.62.0+dfsg-4build3 [4,504 B]
# Get:153 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-exception-dev amd64 1.62.0.1 [2,864 B]
# Get:154 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-fiber1.62.0 amd64 1.62.0+dfsg-4build3 [25.7 kB]
# Get:155 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-fiber1.62-dev amd64 1.62.0+dfsg-4build3 [29.6 kB]
# Get:156 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-fiber-dev amd64 1.62.0.1 [3,290 B]
# Get:157 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-system1.62-dev amd64 1.62.0+dfsg-4build3 [9,564 B]
# Get:158 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-filesystem1.62-dev amd64 1.62.0+dfsg-4build3 [48.5 kB]
# Get:159 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-filesystem-dev amd64 1.62.0.1 [2,900 B]
# Get:160 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-regex1.62.0 amd64 1.62.0+dfsg-4build3 [262 kB]
# Get:161 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-graph1.62.0 amd64 1.62.0+dfsg-4build3 [93.6 kB]
# Get:162 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-test1.62.0 amd64 1.62.0+dfsg-4build3 [231 kB]
# Get:163 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-test1.62-dev amd64 1.62.0+dfsg-4build3 [276 kB]
# Get:164 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-graph1.62-dev amd64 1.62.0+dfsg-4build3 [102 kB]
# Get:165 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-graph-dev amd64 1.62.0.1 [2,960 B]
# Get:166 http://archive.ubuntu.com/ubuntu artful/main amd64 libnl-3-200 amd64 3.2.29-0ubuntu3 [52.8 kB]
# Get:167 http://archive.ubuntu.com/ubuntu artful/main amd64 libnl-route-3-200 amd64 3.2.29-0ubuntu3 [146 kB]
# Get:168 http://archive.ubuntu.com/ubuntu artful/main amd64 libibverbs1 amd64 1.2.1-2ubuntu1 [30.8 kB]
# Get:169 http://archive.ubuntu.com/ubuntu artful/universe amd64 libpsm-infinipath1 amd64 3.3+19.g67c0807.open-3 [170 kB]
# Get:170 http://archive.ubuntu.com/ubuntu artful/main amd64 librdmacm1 amd64 1.1.0-2 [48.9 kB]
# Get:171 http://archive.ubuntu.com/ubuntu artful/universe amd64 libfabric1 amd64 1.4.0-1 [259 kB]
# Get:172 http://archive.ubuntu.com/ubuntu artful/main amd64 libltdl7 amd64 2.4.6-2 [38.8 kB]
# Get:173 http://archive.ubuntu.com/ubuntu artful/universe amd64 libhwloc5 amd64 1.11.5-1 [101 kB]
# Get:174 http://archive.ubuntu.com/ubuntu artful/main amd64 ocl-icd-libopencl1 amd64 2.2.11-1ubuntu1 [30.3 kB]
# Get:175 http://archive.ubuntu.com/ubuntu artful/universe amd64 libhwloc-plugins amd64 1.11.5-1 [12.2 kB]
# Get:176 http://archive.ubuntu.com/ubuntu artful/universe amd64 libopenmpi2 amd64 2.1.1-6 [2,042 kB]
# Get:177 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-mpi1.62.0 amd64 1.62.0+dfsg-4build3 [46.4 kB]
# Get:178 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-graph-parallel1.62.0 amd64 1.62.0+dfsg-4build3 [62.0 kB]
# Get:179 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-graph-parallel1.62-dev amd64 1.62.0+dfsg-4build3 [64.0 kB]
# Get:180 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-graph-parallel-dev amd64 1.62.0.1 [2,998 B]
# Get:181 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-regex1.62-dev amd64 1.62.0+dfsg-4build3 [310 kB]
# Get:182 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-iostreams1.62.0 amd64 1.62.0+dfsg-4build3 [27.4 kB]
# Get:183 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-iostreams1.62-dev amd64 1.62.0+dfsg-4build3 [32.8 kB]
# Get:184 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-iostreams-dev amd64 1.62.0.1 [2,860 B]
# Get:185 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-locale1.62.0 amd64 1.62.0+dfsg-4build3 [237 kB]
# Get:186 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-locale1.62-dev amd64 1.62.0+dfsg-4build3 [314 kB]
# Get:187 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-locale-dev amd64 1.62.0.1 [3,200 B]
# Get:188 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-log1.62.0 amd64 1.62.0+dfsg-4build3 [372 kB]
# Get:189 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-thread1.62-dev amd64 1.62.0+dfsg-4build3 [47.0 kB]
# Get:190 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-log1.62-dev amd64 1.62.0+dfsg-4build3 [520 kB]
# Get:191 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-log-dev amd64 1.62.0.1 [3,056 B]
# Get:192 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-math1.62.0 amd64 1.62.0+dfsg-4build3 [292 kB]
# Get:193 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-math1.62-dev amd64 1.62.0+dfsg-4build3 [515 kB]
# Get:194 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-math-dev amd64 1.62.0.1 [3,064 B]
# Get:195 http://archive.ubuntu.com/ubuntu artful/universe amd64 openmpi-common all 2.1.1-6 [140 kB]
# Get:196 http://archive.ubuntu.com/ubuntu artful/main amd64 libibverbs-dev amd64 1.2.1-2ubuntu1 [97.5 kB]
# Get:197 http://archive.ubuntu.com/ubuntu artful/main amd64 libnuma-dev amd64 2.0.11-2.1 [32.2 kB]
# Get:198 http://archive.ubuntu.com/ubuntu artful/main amd64 libltdl-dev amd64 2.4.6-2 [162 kB]
# Get:199 http://archive.ubuntu.com/ubuntu artful/universe amd64 libhwloc-dev amd64 1.11.5-1 [163 kB]
# Get:200 http://archive.ubuntu.com/ubuntu artful/universe amd64 libopenmpi-dev amd64 2.1.1-6 [921 kB]
# 72% [200 libopenmpi-dev 0 B/921 kB 0%]
# Get:201 http://archive.ubuntu.com/ubuntu artful/universe amd64 mpi-default-dev amd64 1.8 [3,716 B]
# Get:202 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-mpi1.62-dev amd64 1.62.0+dfsg-4build3 [130 kB]
# Get:203 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-mpi-dev amd64 1.62.0.1 [2,944 B]
# Get:204 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-python1.62.0 amd64 1.62.0+dfsg-4build3 [113 kB]
# Get:205 http://archive.ubuntu.com/ubuntu artful/universe amd64 openmpi-bin amd64 2.1.1-6 [86.9 kB]
# Get:206 http://archive.ubuntu.com/ubuntu artful/universe amd64 mpi-default-bin amd64 1.8 [2,930 B]
# Get:207 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-mpi-python1.62.0 amd64 1.62.0+dfsg-4build3 [209 kB]
# Get:208 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-mpi-python1.62-dev amd64 1.62.0+dfsg-4build3 [24.4 kB]
# Get:209 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-mpi-python-dev amd64 1.62.0.1 [2,992 B]
# Get:210 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-program-options1.62.0 amd64 1.62.0+dfsg-4build3 [136 kB]
# Get:211 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-program-options1.62-dev amd64 1.62.0+dfsg-4build3 [159 kB]
# Get:212 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-program-options-dev amd64 1.62.0.1 [2,886 B]
# Get:213 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-python1.62-dev amd64 1.62.0+dfsg-4build3 [142 kB]
# Get:214 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-python-dev amd64 1.62.0.1 [3,254 B]
# Get:215 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-random1.62.0 amd64 1.62.0+dfsg-4build3 [11.2 kB]
# Get:216 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-random1.62-dev amd64 1.62.0+dfsg-4build3 [10.5 kB]
# Get:217 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-random-dev amd64 1.62.0.1 [2,866 B]
# Get:218 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-regex-dev amd64 1.62.0.1 [3,120 B]
# Get:219 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-serialization-dev amd64 1.62.0.1 [3,094 B]
# Get:220 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-signals1.62.0 amd64 1.62.0+dfsg-4build3 [30.6 kB]
# Get:221 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-signals1.62-dev amd64 1.62.0+dfsg-4build3 [33.4 kB]
# Get:222 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-signals-dev amd64 1.62.0.1 [2,928 B]
# Get:223 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-system-dev amd64 1.62.0.1 [3,006 B]
# Get:224 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-test-dev amd64 1.62.0.1 [2,902 B]
# Get:225 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-thread-dev amd64 1.62.0.1 [2,882 B]
# Get:226 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-timer1.62.0 amd64 1.62.0+dfsg-4build3 [10.1 kB]
# Get:227 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-timer1.62-dev amd64 1.62.0+dfsg-4build3 [9,792 B]
# Get:228 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-timer-dev amd64 1.62.0.1 [2,986 B]
# Get:229 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-type-erasure1.62.0 amd64 1.62.0+dfsg-4build3 [18.1 kB]
# Get:230 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-type-erasure1.62-dev amd64 1.62.0+dfsg-4build3 [17.4 kB]
# Get:231 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-type-erasure-dev amd64 1.62.0.1 [2,960 B]
# Get:232 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-wave1.62.0 amd64 1.62.0+dfsg-4build3 [179 kB]
# Get:233 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-wave1.62-dev amd64 1.62.0+dfsg-4build3 [227 kB]
# Get:234 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-wave-dev amd64 1.62.0.1 [2,896 B]
# Get:235 http://archive.ubuntu.com/ubuntu artful/universe amd64 libboost-all-dev amd64 1.62.0.1 [2,230 B]
# Get:236 http://archive.ubuntu.com/ubuntu artful/main amd64 libdbus-1-dev amd64 1.10.22-1ubuntu1 [161 kB]
# Get:237 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-dmx-dev all 1:2.3.1-2 [5,848 B]
# Get:238 http://archive.ubuntu.com/ubuntu artful/main amd64 libdmx-dev amd64 1:1.1.3-1 [34.4 kB]
# Get:239 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-dev amd64 2.4.83-1 [234 kB]
# Get:240 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-dri2-dev all 2.8-2 [12.6 kB]
# Get:241 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-gl-dev all 1.4.17-1 [17.9 kB]
# Get:242 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-xext-dev all 7.3.0-1 [212 kB]
# Get:243 http://archive.ubuntu.com/ubuntu artful/main amd64 libxext-dev amd64 2:1.3.3-1 [82.1 kB]
# Get:244 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-xf86vidmode-dev all 2.3.1-2 [6,116 B]
# Get:245 http://archive.ubuntu.com/ubuntu artful/main amd64 libxxf86vm-dev amd64 1:1.1.4-1 [13.3 kB]
# Get:246 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-fixes-dev all 1:5.0-2ubuntu2 [14.2 kB]
# Get:247 http://archive.ubuntu.com/ubuntu artful/main amd64 libxfixes-dev amd64 1:5.0.3-1 [11.0 kB]
# Get:248 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-damage-dev all 1:1.2.1-2 [8,286 B]
# Get:249 http://archive.ubuntu.com/ubuntu artful/main amd64 libxdamage-dev amd64 1:1.1.4-3 [5,028 B]
# Get:250 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-glx0-dev amd64 1.12-1ubuntu1 [27.5 kB]
# Get:251 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-dri2-0-dev amd64 1.12-1ubuntu1 [8,376 B]
# Get:252 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-dri3-dev amd64 1.12-1ubuntu1 [5,742 B]
# Get:253 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-randr0 amd64 1.12-1ubuntu1 [16.0 kB]
# Get:254 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-render0-dev amd64 1.12-1ubuntu1 [18.3 kB]
# Get:255 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-randr0-dev amd64 1.12-1ubuntu1 [19.5 kB]
# Get:256 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-shape0-dev amd64 1.12-1ubuntu1 [7,056 B]
# Get:257 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-xfixes0-dev amd64 1.12-1ubuntu1 [11.6 kB]
# Get:258 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-sync-dev amd64 1.12-1ubuntu1 [10.5 kB]
# Get:259 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-present-dev amd64 1.12-1ubuntu1 [6,868 B]
# Get:260 http://archive.ubuntu.com/ubuntu artful/main amd64 libxshmfence-dev amd64 1.2-1 [3,676 B]
# Get:261 http://archive.ubuntu.com/ubuntu artful/main amd64 libx11-xcb-dev amd64 2:1.6.4-3 [9,660 B]
# Get:262 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-bin amd64 1.14.0-1ubuntu0.1 [18.8 kB]
# Get:263 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-dev amd64 1.14.0-1ubuntu0.1 [98.1 kB]
# Get:264 http://archive.ubuntu.com/ubuntu artful/main amd64 libmircore-dev amd64 0.28.0+17.10.20171011.1-0ubuntu1 [26.7 kB]
# Get:265 http://archive.ubuntu.com/ubuntu artful/main amd64 libprotobuf10 amd64 3.0.0-9ubuntu5 [650 kB]
# Get:266 http://archive.ubuntu.com/ubuntu artful/main amd64 libprotobuf-dev amd64 3.0.0-9ubuntu5 [958 kB]
# Get:267 http://archive.ubuntu.com/ubuntu artful/main amd64 libxkbcommon-dev amd64 0.7.1-2 [308 kB]
# Get:268 http://archive.ubuntu.com/ubuntu artful/main amd64 libmircommon-dev amd64 0.28.0+17.10.20171011.1-0ubuntu1 [13.9 kB]
# Get:269 http://archive.ubuntu.com/ubuntu artful/main amd64 libmircookie2 amd64 0.28.0+17.10.20171011.1-0ubuntu1 [24.8 kB]
# Get:270 http://archive.ubuntu.com/ubuntu artful/main amd64 libmircookie-dev amd64 0.28.0+17.10.20171011.1-0ubuntu1 [4,316 B]
# Get:271 http://archive.ubuntu.com/ubuntu artful/main amd64 libmirclient-dev amd64 0.28.0+17.10.20171011.1-0ubuntu1 [47.8 kB]
# Get:272 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libegl1-mesa-dev amd64 17.2.8-0ubuntu0~17.10.1 [19.9 kB]
# Get:273 http://archive.ubuntu.com/ubuntu artful/main amd64 libfontenc-dev amd64 1:1.1.3-1 [13.8 kB]
# Get:274 http://archive.ubuntu.com/ubuntu artful/main amd64 libfs6 amd64 2:1.0.7-1 [22.5 kB]
# Get:275 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-fonts-dev all 2.1.3-1 [67.9 kB]
# Get:276 http://archive.ubuntu.com/ubuntu artful/main amd64 libfs-dev amd64 2:1.0.7-1 [26.8 kB]
# Get:277 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgles2-mesa amd64 17.2.8-0ubuntu0~17.10.1 [13.5 kB]
# 82% [Working]
# Get:278 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgles2-mesa-dev amd64 17.2.8-0ubuntu0~17.10.1 [40.3 kB]
# Get:279 http://archive.ubuntu.com/ubuntu artful/main amd64 libglib2.0-bin amd64 2.54.1-1ubuntu1 [69.8 kB]
# Get:280 http://archive.ubuntu.com/ubuntu artful/main amd64 libglib2.0-dev-bin amd64 2.54.1-1ubuntu1 [84.7 kB]
# Get:281 http://archive.ubuntu.com/ubuntu artful/main amd64 libpcre16-3 amd64 2:8.39-5ubuntu3 [147 kB]
# Get:282 http://archive.ubuntu.com/ubuntu artful/main amd64 libpcre32-3 amd64 2:8.39-5ubuntu3 [138 kB]
# Get:283 http://archive.ubuntu.com/ubuntu artful/main amd64 libpcrecpp0v5 amd64 2:8.39-5ubuntu3 [15.2 kB]
# Get:284 http://archive.ubuntu.com/ubuntu artful/main amd64 libpcre3-dev amd64 2:8.39-5ubuntu3 [536 kB]
# Get:285 http://archive.ubuntu.com/ubuntu artful/main amd64 libglib2.0-dev amd64 2.54.1-1ubuntu1 [1,373 kB]
# Get:286 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 mesa-common-dev amd64 17.2.8-0ubuntu0~17.10.1 [519 kB]
# Get:287 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgl1-mesa-dev amd64 17.2.8-0ubuntu0~17.10.1 [4,436 B]
# Get:288 http://archive.ubuntu.com/ubuntu artful/main amd64 libglu1-mesa-dev amd64 9.0.0-2.1build1 [206 kB]
# Get:289 http://archive.ubuntu.com/ubuntu artful/main amd64 libibus-1.0-dev amd64 1.5.14-2ubuntu1 [143 kB]
# Get:290 http://archive.ubuntu.com/ubuntu artful/main amd64 libice-dev amd64 2:1.0.9-2 [46.8 kB]
# Get:291 http://archive.ubuntu.com/ubuntu artful/main amd64 libpixman-1-dev amd64 0.34.0-1 [245 kB]
# Get:292 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libpulse-mainloop-glib0 amd64 1:10.0-2ubuntu3.1 [22.0 kB]
# Get:293 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libpulse-dev amd64 1:10.0-2ubuntu3.1 [81.5 kB]
# Get:294 http://archive.ubuntu.com/ubuntu artful/universe amd64 libsndio-dev amd64 1.1.0-3 [13.3 kB]
# Get:295 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libxcursor-dev amd64 1:1.1.14-3ubuntu0.1 [26.5 kB]
# Get:296 http://archive.ubuntu.com/ubuntu artful/main amd64 libxi-dev amd64 2:1.7.9-1 [186 kB]
# Get:297 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-xinerama-dev all 1.2.1-2 [4,966 B]
# Get:298 http://archive.ubuntu.com/ubuntu artful/main amd64 libxinerama-dev amd64 2:1.1.3-1 [8,404 B]
# Get:299 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-randr-dev all 1.5.0-1 [33.7 kB]
# Get:300 http://archive.ubuntu.com/ubuntu artful/main amd64 libxrandr-dev amd64 2:1.5.1-1 [24.0 kB]
# Get:301 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-scrnsaver-dev all 1.2.2-1 [25.0 kB]
# Get:302 http://archive.ubuntu.com/ubuntu artful/main amd64 libxss-dev amd64 1:1.2.2-1 [12.7 kB]
# Get:303 http://archive.ubuntu.com/ubuntu artful/main amd64 libsm-dev amd64 2:1.2.2-1 [16.2 kB]
# Get:304 http://archive.ubuntu.com/ubuntu artful/main amd64 libxt-dev amd64 1:1.1.5-1 [395 kB]
# Get:305 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-video-dev all 2.3.3-1 [15.8 kB]
# Get:306 http://archive.ubuntu.com/ubuntu artful/main amd64 libxv-dev amd64 2:1.0.11-1 [32.5 kB]
# Get:307 http://archive.ubuntu.com/ubuntu artful/universe amd64 libsdl2-dev amd64 2.0.6+dfsg1-3ubuntu1 [640 kB]
# Get:308 http://archive.ubuntu.com/ubuntu artful/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:309 http://archive.ubuntu.com/ubuntu artful/main amd64 libxmu-headers all 2:1.1.2-2 [54.3 kB]
# Get:310 http://archive.ubuntu.com/ubuntu artful/main amd64 libxmu-dev amd64 2:1.1.2-2 [49.0 kB]
# Get:311 http://archive.ubuntu.com/ubuntu artful/main amd64 libxpm-dev amd64 1:3.5.12-1 [87.4 kB]
# Get:312 http://archive.ubuntu.com/ubuntu artful/main amd64 libxaw7-dev amd64 2:1.0.13-1 [231 kB]
# Get:313 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcomposite1 amd64 1:0.4.4-2 [6,988 B]
# Get:314 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-composite-dev all 1:0.4.2-2 [10.5 kB]
# Get:315 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcomposite-dev amd64 1:0.4.4-2 [9,136 B]
# Get:316 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libxfont-dev amd64 1:2.0.1-3ubuntu1.1 [123 kB]
# Get:317 http://archive.ubuntu.com/ubuntu artful/main amd64 libxkbfile-dev amd64 1:1.0.9-2 [74.3 kB]
# Get:318 http://archive.ubuntu.com/ubuntu artful/main amd64 libxmuu-dev amd64 2:1.1.2-2 [7,056 B]
# Get:319 http://archive.ubuntu.com/ubuntu artful/main amd64 libxres1 amd64 2:1.0.7-3 [6,492 B]
# Get:320 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-resource-dev all 1.2.0-3 [10.7 kB]
# Get:321 http://archive.ubuntu.com/ubuntu artful/main amd64 libxres-dev amd64 2:1.0.7-3 [6,530 B]
# Get:322 http://archive.ubuntu.com/ubuntu artful/main amd64 libxtst6 amd64 2:1.2.3-1 [12.8 kB]
# Get:323 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-record-dev all 1.14.2-1 [33.6 kB]
# Get:324 http://archive.ubuntu.com/ubuntu artful/main amd64 libxtst-dev amd64 2:1.2.3-1 [15.2 kB]
# Get:325 http://archive.ubuntu.com/ubuntu artful/main amd64 libxvmc1 amd64 2:1.0.10-1 [13.7 kB]
# Get:326 http://archive.ubuntu.com/ubuntu artful/main amd64 libxvmc-dev amd64 2:1.0.10-1 [21.3 kB]
# Get:327 http://archive.ubuntu.com/ubuntu artful/main amd64 x11proto-xf86dga-dev all 2.1-3 [7,288 B]
# ...
# Setting up x11proto-xf86bigfont-dev (1.2.0-3) ...
# Setting up libspeex1:amd64 (1.2~rc1.2-1ubuntu1) ...
# Setting up libxkbfile-dev:amd64 (1:1.0.9-2) ...
# Setting up libxvmc1:amd64 (2:1.0.10-1) ...
# Setting up libxmuu-dev:amd64 (2:1.1.2-2) ...
# Setting up libfftw3-double3:amd64 (3.3.6p2-1) ...
# Setting up libxvidcore4:amd64 (2:1.3.4-1) ...
# Setting up x11proto-record-dev (1.14.2-1) ...
# Setting up libgirepository-1.0-1:amd64 (1.54.1-1) ...
# Setting up libboost-serialization1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libvpx4:amd64 (1.6.1-3) ...
# Setting up python-numpy (1:1.12.1-3.1ubuntu4) ...
# Setting up libboost-exception1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libopus0:amd64 (1.1.2-1ubuntu1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1) ...
# Setting up libmagic-mgc (1:5.32-1ubuntu0.1) ...
# Setting up libva1:amd64 (1.8.3-2) ...
# Setting up libasound2:amd64 (1.1.3-5) ...
# Setting up libopenal-data (1:1.17.2-4) ...
# Setting up libmagic1:amd64 (1:5.32-1ubuntu0.1) ...
# Setting up libgraphite2-3:amd64 (1.3.10-2) ...
# Setting up librhash0 (1.3.4-3) ...
# Setting up libbs2b0:amd64 (3.1.0+dfsg-2.2) ...
# Setting up libboost-iostreams1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up x11proto-xcmisc-dev (1.2.2-1) ...
# Setting up libpsm-infinipath1 (3.3+19.g67c0807.open-3) ...
# Setting up libprotobuf10:amd64 (3.0.0-9ubuntu5) ...
# Setting up libxcb-dri2-0-dev:amd64 (1.12-1ubuntu1) ...
# Setting up libogg0:amd64 (1.3.2-1) ...
# Setting up libxcb-render0-dev:amd64 (1.12-1ubuntu1) ...
# Setting up i965-va-driver:amd64 (1.8.3-1ubuntu1) ...
# Setting up libmircookie2:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up libfontenc-dev:amd64 (1:1.1.3-1) ...
# Setting up libmp3lame0:amd64 (3.99.5+repack1-9build1) ...
# Setting up libxcb-dri3-dev:amd64 (1.12-1ubuntu1) ...
# Setting up gir1.2-glib-2.0:amd64 (1.54.1-1) ...
# Setting up x11proto-xext-dev (7.3.0-1) ...
# Setting up libxcursor1:amd64 (1:1.1.14-3ubuntu0.1) ...
# Setting up libglib2.0-data (2.54.1-1ubuntu1) ...
# Setting up libboost-exception-dev:amd64 (1.62.0.1) ...
# Setting up libusb-1.0-0:amd64 (2:1.0.21-2) ...
# Setting up libcrystalhd3:amd64 (1:0.0~git20110715.fdd2f19-12) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up openmpi-common (2.1.1-6) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up x11proto-xinerama-dev (1.2.1-2) ...
# Setting up autotools-dev (20161112.1) ...
# Setting up libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Setting up x11proto-video-dev (2.3.3-1) ...
# Setting up libice-dev:amd64 (2:1.0.9-2) ...
# Setting up libpixman-1-dev (0.34.0-1) ...
# Setting up libxext-dev:amd64 (2:1.3.3-1) ...
# Setting up x11proto-randr-dev (1.5.0-1) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Setting up x11proto-xf86dri-dev (2.1.1-2) ...
# Setting up libsnappy1v5:amd64 (1.1.6-4) ...
# Setting up libboost-test1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up mesa-va-drivers:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up x11proto-gl-dev (1.4.17-1) ...
# Setting up x11proto-present-dev (1.1-1) ...
# Setting up libltdl7:amd64 (2.4.6-2) ...
# Setting up libavc1394-0:amd64 (0.5.4-4) ...
# Setting up libboost-atomic1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libx265-130:amd64 (2.5-2) ...
# Setting up libboost-math1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libxcomposite1:amd64 (1:0.4.4-2) ...
# Setting up libzvbi-common (0.2.35-13) ...
# Setting up libfribidi0:amd64 (0.19.7-1) ...
# Setting up libxcb-shm0:amd64 (1.12-1ubuntu1) ...
# Setting up x11proto-resource-dev (1.2.0-3) ...
# Setting up libxcb-shape0:amd64 (1.12-1ubuntu1) ...
# Setting up x11proto-xf86dga-dev (2.1-3) ...
# Setting up libfs6:amd64 (2:1.0.7-1) ...
# Setting up libxv1:amd64 (2:1.0.11-1) ...
# Setting up libxcb-glx0-dev:amd64 (1.12-1ubuntu1) ...
# Setting up libxxf86dga-dev:amd64 (2:1.1.4-1) ...
# Setting up x11proto-scrnsaver-dev (1.2.2-1) ...
# Setting up libxkbcommon0:amd64 (0.7.1-2) ...
# Setting up libpcrecpp0v5:amd64 (2:8.39-5ubuntu3) ...
# Setting up libpcre32-3:amd64 (2:8.39-5ubuntu3) ...
# Setting up libboost-python1.62.0 (1.62.0+dfsg-4build3) ...
# Setting up libibus-1.0-5:amd64 (1.5.14-2ubuntu1) ...
# Setting up libcdio-paranoia1:amd64 (0.83-4.2ubuntu1) ...
# Setting up libva-drm1:amd64 (1.8.3-2) ...
# Setting up libdmx1:amd64 (1:1.1.3-1) ...
# Setting up libpcre16-3:amd64 (2:8.39-5ubuntu3) ...
# Setting up libboost-dev:amd64 (1.62.0.1) ...
# Setting up libgme0:amd64 (0.6.1-1) ...
# Setting up libnuma-dev:amd64 (2.0.11-2.1) ...
# Setting up libbdplus0:amd64 (0.1.2-2) ...
# Setting up ocl-icd-libopencl1:amd64 (2.2.11-1ubuntu1) ...
# Setting up libzvbi0:amd64 (0.2.35-13) ...
# Setting up libsamplerate0:amd64 (0.1.9-1) ...
# Setting up libsndio6.1:amd64 (1.1.0-3) ...
# Setting up libnl-3-200:amd64 (3.2.29-0ubuntu3) ...
# Setting up libvorbis0a:amd64 (1.3.5-4ubuntu0.2) ...
# Setting up libboost-signals1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libxxf86vm-dev:amd64 (1:1.1.4-1) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9ubuntu5) ...
# Setting up libmpg123-0:amd64 (1.25.6-1) ...
# Setting up libglib2.0-bin (2.54.1-1ubuntu1) ...
# Setting up libslang2:amd64 (2.3.1-5ubuntu1) ...
# Setting up libudev-dev:amd64 (234-2ubuntu12.4) ...
# Setting up libgles2-mesa:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libboost-context1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libwayland-cursor0:amd64 (1.14.0-1ubuntu0.1) ...
# Setting up libgsm1:amd64 (1.0.13-4) ...
# Setting up libxrandr2:amd64 (2:1.5.1-1) ...
# Setting up libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Setting up libboost-system1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libva-x11-1:amd64 (1.8.3-2) ...
# Setting up libxcb-sync-dev:amd64 (1.12-1ubuntu1) ...
# Setting up liblzo2-2:amd64 (2.08-1.2) ...
# Setting up libboost-program-options-dev:amd64 (1.62.0.1) ...
# Setting up libwrap0:amd64 (7.6.q-26) ...
# Setting up libwayland-server0:amd64 (1.14.0-1ubuntu0.1) ...
# Setting up libwebp6:amd64 (0.6.0-3) ...
# Setting up libjsoncpp1:amd64 (1.7.4-3) ...
# Setting up libvorbisfile3:amd64 (1.3.5-4ubuntu0.2) ...
# Setting up libboost-atomic1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-serialization-dev:amd64 (1.62.0.1) ...
# Setting up libboost-tools-dev (1.62.0.1) ...
# Setting up libboost-date-time1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libcairo2:amd64 (1.14.10-1ubuntu1) ...
# Setting up libboost-context1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libasound2-dev:amd64 (1.1.3-5) ...
# Setting up libdbus-1-dev:amd64 (1.10.22-1ubuntu1) ...
# Setting up libxcb-randr0-dev:amd64 (1.12-1ubuntu1) ...
# Setting up libsm-dev:amd64 (2:1.2.2-1) ...
# Setting up gir1.2-ibus-1.0:amd64 (1.5.14-2ubuntu1) ...
# Setting up libpcre3-dev:amd64 (2:8.39-5ubuntu3) ...
# Setting up swig (3.0.10-1.2) ...
# Setting up libxkbcommon-dev (0.7.1-2) ...
# Setting up libavutil55:amd64 (7:3.3.4-2) ...
# Setting up mesa-common-dev:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libltdl-dev:amd64 (2.4.6-2) ...
# Setting up libboost-atomic-dev:amd64 (1.62.0.1) ...
# Setting up libopencv-core3.1:amd64 (3.1.0+dfsg1-1~exp1ubuntu3) ...
# Setting up libopenmpt0:amd64 (0.2.8760~beta27-1) ...
# Setting up libarchive13:amd64 (3.2.2-3.1) ...
# Setting up libboost-regex1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-graph1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-thread1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libmirprotobuf3:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up libboost-random1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libflite1:amd64 (2.0.0-release-4) ...
# Setting up libsndio-dev:amd64 (1.1.0-3) ...
# Setting up x11proto-fixes-dev (1:5.0-2ubuntu2) ...
# Setting up libboost-python1.62-dev (1.62.0+dfsg-4build3) ...
# Setting up mesa-vdpau-drivers:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libdmx-dev:amd64 (1:1.1.3-1) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9ubuntu5) ...
# Setting up libgbm1:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libboost-iostreams1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libflac8:amd64 (1.3.2-1) ...
# Setting up libboost-fiber1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libxres-dev (2:1.0.7-3) ...
# Setting up libharfbuzz0b:amd64 (1.4.2-1) ...
# Setting up libdc1394-22:amd64 (2.2.5-1) ...
# Setting up libnl-route-3-200:amd64 (3.2.29-0ubuntu3) ...
# Setting up libboost-fiber1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-fiber-dev:amd64 (1.62.0.1) ...
# Setting up libmircookie-dev:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up libboost-date-time-dev:amd64 (1.62.0.1) ...
# Setting up file (1:5.32-1ubuntu0.1) ...
# Setting up libswresample2:amd64 (7:3.3.4-2) ...
# Setting up tcpd (7.6.q-26) ...
# Setting up libxss-dev:amd64 (1:1.2.2-1) ...
# Setting up libhwloc5:amd64 (1.11.5-1) ...
# Setting up libboost-test1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libglib2.0-dev:amd64 (2.54.1-1ubuntu1) ...
# Setting up libboost-type-erasure1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-locale1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libxfont-dev (1:2.0.1-3ubuntu1.1) ...
# Setting up libhwloc-plugins (1.11.5-1) ...
# Setting up x11proto-damage-dev (1:1.2.1-2) ...
# Setting up libibus-1.0-dev:amd64 (1.5.14-2ubuntu1) ...
# Setting up libboost-system1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libswscale4:amd64 (7:3.3.4-2) ...
# Setting up libboost-math1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-iostreams-dev:amd64 (1.62.0.1) ...
# Setting up libboost-locale1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libwebpmux3:amd64 (0.6.0-3) ...
# Setting up libopencv-imgproc3.1:amd64 (3.1.0+dfsg1-1~exp1ubuntu3) ...
# Setting up va-driver-all:amd64 (1.8.3-2) ...
# Setting up libboost-filesystem1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1) ...
# Setting up libxcb-shape0-dev:amd64 (1.12-1ubuntu1) ...
# Setting up libpostproc54:amd64 (7:3.3.4-2) ...
# Setting up libjack-jackd2-0:amd64 (1.9.10+20150825git1ed50c92~dfsg-5ubuntu1) ...
# Setting up libfs-dev:amd64 (2:1.0.7-1) ...
# Setting up libboost-signals1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-context-dev:amd64 (1.62.0.1) ...
# Setting up libopenal1:amd64 (1:1.17.2-4) ...
# Setting up libboost-regex-dev:amd64 (1.62.0.1) ...
# Setting up libboost-test-dev:amd64 (1.62.0.1) ...
# Setting up librubberband2v5:amd64 (1.8.1-6ubuntu2) ...
# Setting up dbus (1.10.22-1ubuntu1) ...
# Setting up libvorbisenc2:amd64 (1.3.5-4ubuntu0.2) ...
# Setting up libcaca0:amd64 (0.99.beta19-2build2~gcc5.2) ...
# Setting up libmircore1:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up libwayland-dev:amd64 (1.14.0-1ubuntu0.1) ...
# Setting up cmake (3.9.1-1) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-14) ...
# Setting up libxfixes-dev:amd64 (1:5.0.3-1) ...
# Setting up libboost-math-dev:amd64 (1.62.0.1) ...
# Setting up x11proto-composite-dev (1:0.4.2-2) ...
# Setting up libboost-chrono1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-random1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-signals-dev:amd64 (1.62.0.1) ...
# Setting up libboost-python-dev (1.62.0.1) ...
# Setting up vdpau-driver-all:amd64 (1.1.1-3ubuntu1) ...
# Setting up libboost-locale-dev:amd64 (1.62.0.1) ...
# Setting up libtool (2.4.6-2) ...
# Setting up libibverbs1 (1.2.1-2ubuntu1) ...
# Setting up libxcursor-dev:amd64 (1:1.1.14-3ubuntu0.1) ...
# Setting up libxt-dev:amd64 (1:1.1.5-1) ...
# Setting up libboost-wave1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-filesystem1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-timer1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libavresample3:amd64 (7:3.3.4-2) ...
# Setting up libhwloc-dev:amd64 (1.11.5-1) ...
# Setting up libboost-coroutine1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Setting up libxmu-dev:amd64 (2:1.1.2-2) ...
# Setting up libxcb-xfixes0-dev:amd64 (1.12-1ubuntu1) ...
# Setting up libxaw7-dev:amd64 (2:1.0.13-1) ...
# Setting up libboost-system-dev:amd64 (1.62.0.1) ...
# Setting up libboost-log1.62.0 (1.62.0+dfsg-4build3) ...
# Setting up libboost-graph1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libavcodec57:amd64 (7:3.3.4-2) ...
# Setting up libass9:amd64 (1:0.13.7-2) ...
# Setting up libxdamage-dev:amd64 (1:1.1.4-3) ...
# Setting up libboost-type-erasure1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-type-erasure-dev:amd64 (1.62.0.1) ...
# Setting up libxvmc-dev:amd64 (2:1.0.10-1) ...
# Setting up librdmacm1 (1.1.0-2) ...
# Setting up libboost-filesystem-dev:amd64 (1.62.0.1) ...
# Setting up libboost-chrono1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-timer1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libsndfile1:amd64 (1.0.28-4) ...
# Setting up libboost-random-dev:amd64 (1.62.0.1) ...
# Setting up libboost-thread1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libboost-wave1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libmircommon7:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up libboost-coroutine1.62-dev:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libxcb-present-dev:amd64 (1.12-1ubuntu1) ...
# Setting up libxi-dev:amd64 (2:1.7.9-1) ...
# Setting up libboost-coroutine-dev:amd64 (1.62.0.1) ...
# Setting up libibverbs-dev (1.2.1-2ubuntu1) ...
# Setting up libboost-log1.62-dev (1.62.0+dfsg-4build3) ...
# Setting up libchromaprint1:amd64 (1.4.2-1) ...
# Setting up libboost-thread-dev:amd64 (1.62.0.1) ...
# Setting up libfabric1 (1.4.0-1) ...
# Setting up libboost-chrono-dev:amd64 (1.62.0.1) ...
# Setting up libboost-graph-dev:amd64 (1.62.0.1) ...
# Setting up libmirclient9:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up libboost-timer-dev:amd64 (1.62.0.1) ...
# Setting up libpulse0:amd64 (1:10.0-2ubuntu3.1) ...
# Setting up libxtst-dev:amd64 (2:1.2.3-1) ...
# Setting up libboost-log-dev (1.62.0.1) ...
# Setting up libgl1-mesa-dev:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libmircommon-dev:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up libboost-wave-dev:amd64 (1.62.0.1) ...
# Setting up libopenmpi2:amd64 (2.1.1-6) ...
# Setting up libavformat57:amd64 (7:3.3.4-2) ...
# Setting up libegl1-mesa:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/mesa-egl/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_EGL.conf (x86_64-linux-gnu_egl_conf) in auto mode
# Setting up libboost-mpi1.62.0 (1.62.0+dfsg-4build3) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.0-2.1build1) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:10.0-2ubuntu3.1) ...
# Setting up libpulse-dev:amd64 (1:10.0-2ubuntu3.1) ...
# Setting up libopenmpi-dev (2.1.1-6) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/openmpi/include to provide /usr/include/mpi (mpi) in auto mode
# Setting up libmirclient-dev:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up libavfilter6:amd64 (7:3.3.4-2) ...
# Setting up openmpi-bin (2.1.1-6) ...
# update-alternatives: using /usr/bin/mpirun.openmpi to provide /usr/bin/mpirun (mpirun) in auto mode
# Setting up mpi-default-dev (1.8) ...
# Setting up libboost-graph-parallel1.62.0 (1.62.0+dfsg-4build3) ...
# Setting up libwayland-egl1-mesa:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libegl1-mesa-dev:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libboost-graph-parallel1.62-dev (1.62.0+dfsg-4build3) ...
# Setting up libboost-mpi1.62-dev (1.62.0+dfsg-4build3) ...
# Setting up mir-client-platform-mesa-dev:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up mpi-default-bin (1.8) ...
# Setting up libboost-mpi-python1.62.0 (1.62.0+dfsg-4build3) ...
# Setting up libgles2-mesa-dev:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libsdl2-2.0-0:amd64 (2.0.6+dfsg1-3ubuntu1) ...
# Setting up libboost-graph-parallel-dev (1.62.0.1) ...
# Setting up libboost-mpi-dev (1.62.0.1) ...
# Setting up libsdl2-dev:amd64 (2.0.6+dfsg1-3ubuntu1) ...
# Setting up xserver-xorg-dev (2:1.19.5-0ubuntu2) ...
# Setting up libboost-mpi-python1.62-dev (1.62.0+dfsg-4build3) ...
# Setting up xorg-dev (1:7.7+19ubuntu3) ...
# Setting up libavdevice57:amd64 (7:3.3.4-2) ...
# Setting up libboost-mpi-python-dev (1.62.0.1) ...
# Setting up libboost-all-dev (1.62.0.1) ...
# Setting up ffmpeg (7:3.3.4-2) ...
# Setting up libav-tools (7:3.3.4-2) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...

# %%
# !pip install gym
# !pip install "gym[atari]"
# Out:
# Requirement already satisfied: gym[atari] in /usr/local/lib/python3.6/dist-packages (0.10.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (1.11.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (1.14.5)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (1.3.2)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (2.18.4)
# Requirement already satisfied: Pillow; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (4.0.0)
# Collecting atari-py>=0.1.1; extra == "atari" (from gym[atari])
#   Using cached https://files.pythonhosted.org/packages/8b/38/3c6716ac9031a686cc3228f3855e48c08a40e4d7c490dd4c21c65b465205/atari-py-0.1.1.tar.gz
# Requirement already satisfied: PyOpenGL; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (3.1.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym[atari]) (0.16.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]) (2018.4.16)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]) (2.6)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow; extra == "atari"->gym[atari]) (0.45.1)
# Building wheels for collected packages: atari-py
# |
# done
#   Stored in directory: /content/.cache/pip/wheels/ac/79/85/b21b404d3469c3028aea3b7a1dfe9d9bf9827a20cee6a118bd
# Successfully built atari-py
# Installing collected packages: atari-py
# Successfully installed atari-py-0.1.1

# %%
import gym

def make_env():
    env = gym.make("KungFuMasterDeterministic-v0")
    env = PreprocessAtari(env, height=42, width=42,
                          crop = lambda img: img[60:-30, 5:],
                          dim_order = 'tensorflow',
                          color=False, n_frames=4,
                          reward_scale = 0.01)
    return env

env = make_env()

obs_shape = env.observation_space.shape
n_actions = env.action_space.n

print("Observation shape:", obs_shape)
print("Num actions:", n_actions)
print("Action names:", env.env.env.get_action_meanings())
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Observation shape: (42, 42, 4)
# Num actions: 14
# Action names: ['NOOP', 'UP', 'RIGHT', 'LEFT', 'DOWN', 'DOWNRIGHT', 'DOWNLEFT', 'RIGHTFIRE', 'LEFTFIRE', 'DOWNFIRE', 'UPRIGHTFIRE', 'UPLEFTFIRE', 'DOWNRIGHTFIRE', 'DOWNLEFTFIRE']

# %%
s = env.reset()
for _ in range(100):
    s, _, _, _ = env.step(env.action_space.sample())

plt.title('Game image')
plt.imshow(env.render('rgb_array'))
plt.show()

plt.title('Agent observation (4-frame buffer)')
plt.imshow(s.transpose([0,2,1]).reshape([42,-1]))
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
import tensorflow as tf
tf.reset_default_graph()
sess = tf.InteractiveSession()

# %%
from keras.layers import Conv2D, Dense, Flatten, Input
import keras
from keras.models import Model, Sequential

class Agent:
    def __init__(self, name, state_shape, n_actions, reuse=False):
        """A simple actor-critic agent"""
        
        with tf.variable_scope(name, reuse=reuse):
            
            # Prepare neural network architecture
            ### Your code here: prepare any necessary layers, variables, etc.
#             self.network = Sequential()
            
#             # similar architecture as the dqn
#             self.network.add(Conv2D(32, (3, 3), strides=2, activation='relu', input_shape=state_shape))
#             self.network.add(Conv2D(32, (3, 3), strides=2, activation='relu'))
#             self.network.add(Conv2D(32, (3, 3), strides=2, activation='relu'))
#             self.network.add(Flatten())
#             self.network.add(Dense(128, activation='relu'))
            
#             # logits for n_actions and 1 unit for the state value
#             self.network.add(Dense(n_actions+1, activation='linear'))


            ####
            inputs = Input(shape=state_shape)
            x = Conv2D(32, (3, 3), strides=2, activation='relu')(inputs)
            x = Conv2D(32, (3, 3), strides=2, activation='relu')(x)
            x = Conv2D(32, (3, 3), strides=2, activation='relu')(x)
            x = Flatten()(x)
            x = Dense(128, activation='relu')(x)
            
            # two different output layers
            logits = Dense(n_actions, activation='linear')(x)
            state_value = Dense(1, activation='linear')(x)
            
            self.network = Model(inputs=inputs, outputs=[logits, state_value])
            
            
            # prepare a graph for agent step
            self.state_t = tf.placeholder('float32', [None,] + list(state_shape))
            self.agent_outputs = self.symbolic_step(self.state_t)
        
    def symbolic_step(self, state_t):
        """Takes agent's previous step and observation, returns next state and whatever it needs to learn (tf tensors)"""
        
        # Apply neural network
        ### Your code here: apply agent's neural network to get policy logits and state values.
#         network_output = self.network(state_t)

#         logits = network_output[:,1:]
#         state_value = network_output[:,0]
        
        
        logits, state_value = self.network(state_t)
        state_value = state_value[:, 0]
        
        assert tf.is_numeric_tensor(state_value) and state_value.shape.ndims == 1, \
            "please return 1D tf tensor of state values [you got %s]" % repr(state_value)
        assert tf.is_numeric_tensor(logits) and logits.shape.ndims == 2, \
            "please return 2d tf tensor of logits [you got %s]" % repr(logits)
        # hint: if you triggered state_values assert with your shape being [None, 1], 
        # just select [:, 0]-th element of state values as new state values
        
        return (logits, state_value)
    
    def step(self, state_t):
        """Same as symbolic step except it operates on numpy arrays"""
        sess = tf.get_default_session()
        return sess.run(self.agent_outputs, {self.state_t: state_t})
    
    def sample_actions(self, agent_outputs):
        """pick actions given numeric agent outputs (np arrays)"""
        logits, state_values = agent_outputs
        policy = np.exp(logits) / np.sum(np.exp(logits), axis=-1, keepdims=True)
        return np.array([np.random.choice(len(p), p=p) for p in policy])
# Out:
# Using TensorFlow backend.

# %%
agent = Agent("agent", obs_shape, n_actions)
sess.run(tf.global_variables_initializer())

# %%
state = [env.reset()]
logits, value = agent.step(state)
print("action logits:\n", logits)
print("state values:\n", value)
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# action logits:
#  [[-0.04011825 -0.03369963 -0.05471736 -0.01447331 -0.03145602  0.0269252
#    0.06747915 -0.00501616 -0.00702886  0.01228065 -0.05536278  0.02292078
#   -0.05011498  0.01017556]]
# state values:
#  [0.00383585]

# %%
def evaluate(agent, env, n_games=1):
    """Plays an a game from start till done, returns per-game rewards """

    game_rewards = []
    for _ in range(n_games):
        state = env.reset()
        
        total_reward = 0
        while True:
            action = agent.sample_actions(agent.step([state]))[0]
            state, reward, done, info = env.step(action)
            total_reward += reward
            if done: break
                
        game_rewards.append(total_reward)
    return game_rewards

# %%
env_monitor = gym.wrappers.Monitor(env, directory="kungfu_videos", force=True)
rw = evaluate(agent, env_monitor, n_games=3,)
env_monitor.close()
print (rw)
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# [3.0, 2.0, 9.0]

# %%
from IPython.display import HTML
import os

video_names = list(filter(lambda s:s.endswith(".mp4"),os.listdir("./kungfu_videos/")))

HTML("""
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format("./kungfu_videos/"+video_names[0])) #this may or may not be _last_ video. Try other indices
# Out:
# <video width="640" height="480" controls>
#   <source src="./kungfu_videos/openaigym.video.0.88.video000000.mp4" type="video/mp4">
# </video>

# %%
class EnvBatch:
    def __init__(self, n_envs = 10):
        """ Creates n_envs environments and babysits them for ya' """
        self.envs = [make_env() for _ in range(n_envs)]
        
    def reset(self):
        """ Reset all games and return [n_envs, *obs_shape] observations """
        return np.array([env.reset() for env in self.envs])
    
    def step(self, actions):
        """
        Send a vector[batch_size] of actions into respective environments
        :returns: observations[n_envs, *obs_shape], rewards[n_envs], done[n_envs,], info[n_envs]
        """
        results = [env.step(a) for env, a in zip(self.envs, actions)]
        new_obs, rewards, done, infos = map(np.array, zip(*results))
        
        # reset environments automatically
        for i in range(len(self.envs)):
            if done[i]:
                new_obs[i] = self.envs[i].reset()
        
        return new_obs, rewards, done, infos

# %%
env_batch = EnvBatch(10)

batch_states = env_batch.reset()

batch_actions = agent.sample_actions(agent.step(batch_states))

batch_next_states, batch_rewards, batch_done, _ = env_batch.step(batch_actions)

print("State shape:", batch_states.shape)
print("Actions:", batch_actions[:3])
print("Rewards:", batch_rewards[:3])
print("Done:", batch_done[:3])
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# State shape: (10, 42, 42, 4)
# Actions: [13 11  8]
# Rewards: [0. 0. 0.]
# Done: [False False False]
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
# These placeholders mean exactly the same as in "Let's try it out" section above
states_ph = tf.placeholder('float32', [None,] + list(obs_shape))    
next_states_ph = tf.placeholder('float32', [None,] + list(obs_shape))
actions_ph = tf.placeholder('int32', (None,))
rewards_ph = tf.placeholder('float32', (None,))
is_done_ph = tf.placeholder('float32', (None,))

# %%
# logits[n_envs, n_actions] and state_values[n_envs, n_actions]
logits, state_values = agent.symbolic_step(states_ph)
next_logits, next_state_values = agent.symbolic_step(next_states_ph)
next_state_values = next_state_values * (1 - is_done_ph)

# probabilities and log-probabilities for all actions
probs = tf.nn.softmax(logits)            # [n_envs, n_actions]
logprobs = tf.nn.log_softmax(logits)     # [n_envs, n_actions]

# log-probabilities only for agent's chosen actions
logp_actions = tf.reduce_sum(logprobs * tf.one_hot(actions_ph, n_actions), axis=-1) # [n_envs,]

# %%
# compute advantage using rewards_ph, state_values and next_state_values
gamma = 0.99
advantage = rewards_ph + gamma*next_state_values - state_values

assert advantage.shape.ndims == 1, "please compute advantage for each sample, vector of shape [n_envs,]"

# compute policy entropy given logits_seq. Mind the "-" sign!
entropy =  -tf.reduce_sum(probs * logprobs, 1, name="entropy")

assert entropy.shape.ndims == 1, "please compute pointwise entropy vector of shape [n_envs,] "



actor_loss =  - tf.reduce_mean(logp_actions * tf.stop_gradient(advantage)) - 0.001 * tf.reduce_mean(entropy)

# compute target state values using temporal difference formula. Use rewards_ph and next_step_values
target_state_values = rewards_ph+gamma*next_state_values

critic_loss = tf.reduce_mean((state_values - tf.stop_gradient(target_state_values))**2 )

train_step = tf.train.AdamOptimizer(1e-4).minimize(actor_loss + critic_loss)
sess.run(tf.global_variables_initializer())

# %%
# Sanity checks to catch some errors. Specific to KungFuMaster in assignment's default setup.
l_act, l_crit, adv, ent = sess.run([actor_loss, critic_loss, advantage, entropy], feed_dict = {
        states_ph: batch_states,
        actions_ph: batch_actions,
        next_states_ph: batch_states,
        rewards_ph: batch_rewards,
        is_done_ph: batch_done,
    })

assert abs(l_act) < 100 and abs(l_crit) < 100, "losses seem abnormally large"
assert 0 <= ent.mean() <= np.log(n_actions), "impossible entropy value, double-check the formula pls"
if ent.mean() < np.log(n_actions) / 2: print("Entropy is too low for untrained agent")
print("You just might be fine!")
# Out:
# You just might be fine!

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading https://files.pythonhosted.org/packages/93/24/6ab1df969db228aed36a648a8959d1027099ce45fad67532b9673d533318/tqdm-4.23.4-py2.py3-none-any.whl (42kB)
#     100% |████████████████████████████████| 51kB 4.9MB/s
# Installing collected packages: tqdm
# Successfully installed tqdm-4.23.4

# %%
from IPython.display import clear_output
from tqdm import trange
from pandas import ewma
env_batch = EnvBatch(10)
batch_states = env_batch.reset()

rewards_history = []
entropy_history = []
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
for i in trange(100000): 
    
    batch_actions = agent.sample_actions(agent.step(batch_states))
    batch_next_states, batch_rewards, batch_done, _ = env_batch.step(batch_actions)
    
    feed_dict = {
        states_ph: batch_states,
        actions_ph: batch_actions,
        next_states_ph: batch_next_states,
        rewards_ph: batch_rewards,
        is_done_ph: batch_done,
    }
    batch_states = batch_next_states
    
    _, ent_t = sess.run([train_step, entropy], feed_dict)
    entropy_history.append(np.mean(ent_t))

    if i % 500 == 0: 
        if i % 2500 == 0:
            rewards_history.append(np.mean(evaluate(agent, env, n_games=3)))
            if rewards_history[-1] >= 50:
                print("Your agent has earned the yellow belt")

        clear_output(True)
        plt.figure(figsize=[8,4])
        plt.subplot(1,2,1)
        plt.plot(rewards_history, label='rewards')
        plt.plot(ewma(np.array(rewards_history),span=10), marker='.', label='rewards ewma@10')
        plt.title("Session rewards"); plt.grid(); plt.legend()
        
        plt.subplot(1,2,2)
        plt.plot(entropy_history, label='entropy')
        plt.plot(ewma(np.array(entropy_history),span=1000), label='entropy ewma@1000')
        plt.title("Policy entropy"); plt.grid(); plt.legend()        
        plt.show()
# Out:
# 100%|██████████| 100000/100000 [59:35<00:00, 27.97it/s]

# %%
env_monitor = gym.wrappers.Monitor(env, directory="kungfu_videos", force=True)
final_rewards = evaluate(agent, env_monitor, n_games=1,)
env_monitor.close()
print("Final mean reward:", np.mean(final_rewards))

video_names = list(filter(lambda s:s.endswith(".mp4"),os.listdir("./kungfu_videos/")))
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# Final mean reward: 72.0
